# %%
from AnoGraph import Anograph, AnoEdgeGlobal
from river.stream import iter_pandas
import time
import pandas as pd
from sklearn.metrics import roc_auc_score
import numpy as np
# Out:
# c:\Users\victo\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # DARPA Dataset

# %%
darpa = pd.read_csv('./data/DARPA/Data.csv', header=None, names=['src', 'dst', 'time'])
darpa_label_anograph = pd.read_csv('./data/DARPA/Label.csv', header=None, names=['label'])
darpa_label_anoedge = darpa_label_anograph.copy()

# %% [markdown]
# ## AnoGraph

# %% [markdown]
# ### Hyperparameters

# %%
time_window = 30
edge_threshold = 50 
rows = 2
buckets = 32
anograph = Anograph(time_window, edge_threshold, rows, buckets)

# %% [markdown]
# ### Preprocessing labels for AnoGraph

# %%
darpa_label_anograph['time'] = (darpa['time'].copy() / time_window).astype(int)
darpa_label_anograph = darpa_label_anograph.groupby('time').sum()
darpa_label_anograph['label'] = darpa_label_anograph['label'].apply(lambda x: 1 if x >= edge_threshold else 0)

# %% [markdown]
# ### Define AnoGraph evaluate function

# %%
def evaluate(stream, model, time_window):
    """
    Evaluate a model on a given data stream.

    Parameters
    ----------
    stream : iterable
        A data stream where each element is a tuple (x, _), where x is a dictionary containing
        data for the model to learn, and _ is a placeholder for any additional information.
    model :
        The streaming model to evaluate.
    time_window : int
        Time window for processing data.

    Returns
    -------
    results : pandas.DataFrame
        A DataFrame containing evaluation results, including scores for each time window.
    """
    # Create a copy of the DARPA label DataFrame to store results
    results = darpa_label_anograph.copy()
    results['scores'] = 0.0
    cur_time = 0
    
    # Iterate over the stream data
    for i, (x,_) in enumerate(stream):
        t = x['time']
        
        # Update the model with the current data point
        model.learn_one(x)
        
        # Check if the time has crossed a new time window
        if t // time_window != cur_time:
            
            # Predict the anomaly score for the current time window
            results.loc[cur_time, 'scores'] = model.get_score()
            print(f"{cur_time} / 1554 Time window done.")
            cur_time = t // time_window
            
    # Update results for the last time window
    results.loc[cur_time, 'scores'] = model.get_score()
    print(f"Whole dataset done.")

    return results

# %%
anograph_start = time.time()
darpa_results = evaluate(stream=iter_pandas(X=darpa),
                       model=anograph, time_window=time_window)
anograph_time = time.time() - anograph_start
# Out:
# 0 / 1554 Time window done.
# 1 / 1554 Time window done.
# 2 / 1554 Time window done.
# 3 / 1554 Time window done.
# 4 / 1554 Time window done.
# 5 / 1554 Time window done.
# 6 / 1554 Time window done.
# 7 / 1554 Time window done.
# 8 / 1554 Time window done.
# 9 / 1554 Time window done.
# 10 / 1554 Time window done.
# 11 / 1554 Time window done.
# 12 / 1554 Time window done.
# 13 / 1554 Time window done.
# 14 / 1554 Time window done.
# 15 / 1554 Time window done.
# 16 / 1554 Time window done.
# 17 / 1554 Time window done.
# 18 / 1554 Time window done.
# 19 / 1554 Time window done.
# 20 / 1554 Time window done.
# 21 / 1554 Time window done.
# 22 / 1554 Time window done.
# 23 / 1554 Time window done.
# 24 / 1554 Time window done.
# 25 / 1554 Time window done.
# 26 / 1554 Time window done.
# 27 / 1554 Time window done.
# 28 / 1554 Time window done.
# 29 / 1554 Time window done.
# 30 / 1554 Time window done.
# 31 / 1554 Time window done.
# 32 / 1554 Time window done.
# 33 / 1554 Time window done.
# 34 / 1554 Time window done.
# 35 / 1554 Time window done.
# 36 / 1554 Time window done.
# 37 / 1554 Time window done.
# 38 / 1554 Time window done.
# 39 / 1554 Time window done.
# 40 / 1554 Time window done.
# 41 / 1554 Time window done.
# 42 / 1554 Time window done.
# 43 / 1554 Time window done.
# 44 / 1554 Time window done.
# 45 / 1554 Time window done.
# 46 / 1554 Time window done.
# 47 / 1554 Time window done.
# 48 / 1554 Time window done.
# 49 / 1554 Time window done.
# 50 / 1554 Time window done.
# 51 / 1554 Time window done.
# 52 / 1554 Time window done.
# 53 / 1554 Time window done.
# 54 / 1554 Time window done.
# 55 / 1554 Time window done.
# 56 / 1554 Time window done.
# 57 / 1554 Time window done.
# 58 / 1554 Time window done.
# 59 / 1554 Time window done.
# 60 / 1554 Time window done.
# 61 / 1554 Time window done.
# 62 / 1554 Time window done.
# 63 / 1554 Time window done.
# 64 / 1554 Time window done.
# 65 / 1554 Time window done.
# 66 / 1554 Time window done.
# 67 / 1554 Time window done.
# 68 / 1554 Time window done.
# 69 / 1554 Time window done.
# 70 / 1554 Time window done.
# 71 / 1554 Time window done.
# 72 / 1554 Time window done.
# 73 / 1554 Time window done.
# 74 / 1554 Time window done.
# 75 / 1554 Time window done.
# 76 / 1554 Time window done.
# 77 / 1554 Time window done.
# 78 / 1554 Time window done.
# 79 / 1554 Time window done.
# 80 / 1554 Time window done.
# 81 / 1554 Time window done.
# 82 / 1554 Time window done.
# 83 / 1554 Time window done.
# 84 / 1554 Time window done.
# 85 / 1554 Time window done.
# 86 / 1554 Time window done.
# 87 / 1554 Time window done.
# 88 / 1554 Time window done.
# 89 / 1554 Time window done.
# 90 / 1554 Time window done.
# 91 / 1554 Time window done.
# 92 / 1554 Time window done.
# 93 / 1554 Time window done.
# 94 / 1554 Time window done.
# 95 / 1554 Time window done.
# 96 / 1554 Time window done.
# 97 / 1554 Time window done.
# 98 / 1554 Time window done.
# 99 / 1554 Time window done.
# 100 / 1554 Time window done.
# 101 / 1554 Time window done.
# 102 / 1554 Time window done.
# 103 / 1554 Time window done.
# 104 / 1554 Time window done.
# 105 / 1554 Time window done.
# 106 / 1554 Time window done.
# 107 / 1554 Time window done.
# 108 / 1554 Time window done.
# 109 / 1554 Time window done.
# 110 / 1554 Time window done.
# 111 / 1554 Time window done.
# 112 / 1554 Time window done.
# 113 / 1554 Time window done.
# 114 / 1554 Time window done.
# 115 / 1554 Time window done.
# 116 / 1554 Time window done.
# 117 / 1554 Time window done.
# 118 / 1554 Time window done.
# 119 / 1554 Time window done.
# 120 / 1554 Time window done.
# 121 / 1554 Time window done.
# 122 / 1554 Time window done.
# 123 / 1554 Time window done.
# 124 / 1554 Time window done.
# 125 / 1554 Time window done.
# 126 / 1554 Time window done.
# 127 / 1554 Time window done.
# 128 / 1554 Time window done.
# 129 / 1554 Time window done.
# 130 / 1554 Time window done.
# 131 / 1554 Time window done.
# 132 / 1554 Time window done.
# 133 / 1554 Time window done.
# 134 / 1554 Time window done.
# 135 / 1554 Time window done.
# 136 / 1554 Time window done.
# 137 / 1554 Time window done.
# 138 / 1554 Time window done.
# 139 / 1554 Time window done.
# 140 / 1554 Time window done.
# 141 / 1554 Time window done.
# 142 / 1554 Time window done.
# 143 / 1554 Time window done.
# 144 / 1554 Time window done.
# 145 / 1554 Time window done.
# 146 / 1554 Time window done.
# 147 / 1554 Time window done.
# 148 / 1554 Time window done.
# 149 / 1554 Time window done.
# 150 / 1554 Time window done.
# 151 / 1554 Time window done.
# 152 / 1554 Time window done.
# 153 / 1554 Time window done.
# 154 / 1554 Time window done.
# 155 / 1554 Time window done.
# 156 / 1554 Time window done.
# 157 / 1554 Time window done.
# 158 / 1554 Time window done.
# 159 / 1554 Time window done.
# 160 / 1554 Time window done.
# 161 / 1554 Time window done.
# 162 / 1554 Time window done.
# 163 / 1554 Time window done.
# 164 / 1554 Time window done.
# 165 / 1554 Time window done.
# 166 / 1554 Time window done.
# 167 / 1554 Time window done.
# 168 / 1554 Time window done.
# 169 / 1554 Time window done.
# 170 / 1554 Time window done.
# 171 / 1554 Time window done.
# 172 / 1554 Time window done.
# 173 / 1554 Time window done.
# 174 / 1554 Time window done.
# 175 / 1554 Time window done.
# 176 / 1554 Time window done.
# 177 / 1554 Time window done.
# 178 / 1554 Time window done.
# 179 / 1554 Time window done.
# 180 / 1554 Time window done.
# 181 / 1554 Time window done.
# 182 / 1554 Time window done.
# 183 / 1554 Time window done.
# 184 / 1554 Time window done.
# 185 / 1554 Time window done.
# 186 / 1554 Time window done.
# 187 / 1554 Time window done.
# 188 / 1554 Time window done.
# 189 / 1554 Time window done.
# 190 / 1554 Time window done.
# 191 / 1554 Time window done.
# 192 / 1554 Time window done.
# 193 / 1554 Time window done.
# 194 / 1554 Time window done.
# 195 / 1554 Time window done.
# 196 / 1554 Time window done.
# 197 / 1554 Time window done.
# 198 / 1554 Time window done.
# 199 / 1554 Time window done.
# 200 / 1554 Time window done.
# 201 / 1554 Time window done.
# 202 / 1554 Time window done.
# 203 / 1554 Time window done.
# 204 / 1554 Time window done.
# 205 / 1554 Time window done.
# 206 / 1554 Time window done.
# 207 / 1554 Time window done.
# 208 / 1554 Time window done.
# 209 / 1554 Time window done.
# 210 / 1554 Time window done.
# 211 / 1554 Time window done.
# 212 / 1554 Time window done.
# 213 / 1554 Time window done.
# 214 / 1554 Time window done.
# 215 / 1554 Time window done.
# 216 / 1554 Time window done.
# 217 / 1554 Time window done.
# 218 / 1554 Time window done.
# 219 / 1554 Time window done.
# 220 / 1554 Time window done.
# 221 / 1554 Time window done.
# 222 / 1554 Time window done.
# 223 / 1554 Time window done.
# 224 / 1554 Time window done.
# 225 / 1554 Time window done.
# 226 / 1554 Time window done.
# 227 / 1554 Time window done.
# 228 / 1554 Time window done.
# 229 / 1554 Time window done.
# 230 / 1554 Time window done.
# 231 / 1554 Time window done.
# 232 / 1554 Time window done.
# 233 / 1554 Time window done.
# 234 / 1554 Time window done.
# 235 / 1554 Time window done.
# 236 / 1554 Time window done.
# 237 / 1554 Time window done.
# 238 / 1554 Time window done.
# 239 / 1554 Time window done.
# 240 / 1554 Time window done.
# 241 / 1554 Time window done.
# 242 / 1554 Time window done.
# 243 / 1554 Time window done.
# 244 / 1554 Time window done.
# 245 / 1554 Time window done.
# 246 / 1554 Time window done.
# 247 / 1554 Time window done.
# 248 / 1554 Time window done.
# 249 / 1554 Time window done.
# 250 / 1554 Time window done.
# 251 / 1554 Time window done.
# 252 / 1554 Time window done.
# 253 / 1554 Time window done.
# 254 / 1554 Time window done.
# 255 / 1554 Time window done.
# 256 / 1554 Time window done.
# 257 / 1554 Time window done.
# 258 / 1554 Time window done.
# 259 / 1554 Time window done.
# 260 / 1554 Time window done.
# 261 / 1554 Time window done.
# 262 / 1554 Time window done.
# 263 / 1554 Time window done.
# 264 / 1554 Time window done.
# 265 / 1554 Time window done.
# 266 / 1554 Time window done.
# 267 / 1554 Time window done.
# 268 / 1554 Time window done.
# 269 / 1554 Time window done.
# 270 / 1554 Time window done.
# 271 / 1554 Time window done.
# 272 / 1554 Time window done.
# 273 / 1554 Time window done.
# 274 / 1554 Time window done.
# 275 / 1554 Time window done.
# 276 / 1554 Time window done.
# 277 / 1554 Time window done.
# 278 / 1554 Time window done.
# 279 / 1554 Time window done.
# 280 / 1554 Time window done.
# 281 / 1554 Time window done.
# 282 / 1554 Time window done.
# 283 / 1554 Time window done.
# 284 / 1554 Time window done.
# 285 / 1554 Time window done.
# 286 / 1554 Time window done.
# 287 / 1554 Time window done.
# 288 / 1554 Time window done.
# 289 / 1554 Time window done.
# 290 / 1554 Time window done.
# 291 / 1554 Time window done.
# 292 / 1554 Time window done.
# 293 / 1554 Time window done.
# 294 / 1554 Time window done.
# 295 / 1554 Time window done.
# 296 / 1554 Time window done.
# 297 / 1554 Time window done.
# 298 / 1554 Time window done.
# 299 / 1554 Time window done.
# 300 / 1554 Time window done.
# 301 / 1554 Time window done.
# 302 / 1554 Time window done.
# 303 / 1554 Time window done.
# 304 / 1554 Time window done.
# 305 / 1554 Time window done.
# 306 / 1554 Time window done.
# 307 / 1554 Time window done.
# 308 / 1554 Time window done.
# 309 / 1554 Time window done.
# 310 / 1554 Time window done.
# 311 / 1554 Time window done.
# 312 / 1554 Time window done.
# 313 / 1554 Time window done.
# 314 / 1554 Time window done.
# 315 / 1554 Time window done.
# 316 / 1554 Time window done.
# 317 / 1554 Time window done.
# 318 / 1554 Time window done.
# 319 / 1554 Time window done.
# 320 / 1554 Time window done.
# 321 / 1554 Time window done.
# 322 / 1554 Time window done.
# 323 / 1554 Time window done.
# 324 / 1554 Time window done.
# 325 / 1554 Time window done.
# 326 / 1554 Time window done.
# 327 / 1554 Time window done.
# 328 / 1554 Time window done.
# 329 / 1554 Time window done.
# 330 / 1554 Time window done.
# 331 / 1554 Time window done.
# 332 / 1554 Time window done.
# 333 / 1554 Time window done.
# 334 / 1554 Time window done.
# 335 / 1554 Time window done.
# 336 / 1554 Time window done.
# 337 / 1554 Time window done.
# 338 / 1554 Time window done.
# 339 / 1554 Time window done.
# 340 / 1554 Time window done.
# 341 / 1554 Time window done.
# 342 / 1554 Time window done.
# 343 / 1554 Time window done.
# 344 / 1554 Time window done.
# 345 / 1554 Time window done.
# 346 / 1554 Time window done.
# 347 / 1554 Time window done.
# 348 / 1554 Time window done.
# 349 / 1554 Time window done.
# 350 / 1554 Time window done.
# 351 / 1554 Time window done.
# 352 / 1554 Time window done.
# 353 / 1554 Time window done.
# 354 / 1554 Time window done.
# 355 / 1554 Time window done.
# 356 / 1554 Time window done.
# 357 / 1554 Time window done.
# 358 / 1554 Time window done.
# 359 / 1554 Time window done.
# 360 / 1554 Time window done.
# 361 / 1554 Time window done.
# 362 / 1554 Time window done.
# 363 / 1554 Time window done.
# 364 / 1554 Time window done.
# 365 / 1554 Time window done.
# 366 / 1554 Time window done.
# 367 / 1554 Time window done.
# 368 / 1554 Time window done.
# 369 / 1554 Time window done.
# 370 / 1554 Time window done.
# 371 / 1554 Time window done.
# 372 / 1554 Time window done.
# 373 / 1554 Time window done.
# 374 / 1554 Time window done.
# 375 / 1554 Time window done.
# 376 / 1554 Time window done.
# 377 / 1554 Time window done.
# 378 / 1554 Time window done.
# 379 / 1554 Time window done.
# 380 / 1554 Time window done.
# 381 / 1554 Time window done.
# 382 / 1554 Time window done.
# 383 / 1554 Time window done.
# 384 / 1554 Time window done.
# 385 / 1554 Time window done.
# 386 / 1554 Time window done.
# 387 / 1554 Time window done.
# 388 / 1554 Time window done.
# 389 / 1554 Time window done.
# 390 / 1554 Time window done.
# 391 / 1554 Time window done.
# 392 / 1554 Time window done.
# 393 / 1554 Time window done.
# 394 / 1554 Time window done.
# 395 / 1554 Time window done.
# 396 / 1554 Time window done.
# 397 / 1554 Time window done.
# 398 / 1554 Time window done.
# 399 / 1554 Time window done.
# 400 / 1554 Time window done.
# 401 / 1554 Time window done.
# 402 / 1554 Time window done.
# 403 / 1554 Time window done.
# 404 / 1554 Time window done.
# 405 / 1554 Time window done.
# 406 / 1554 Time window done.
# 407 / 1554 Time window done.
# 408 / 1554 Time window done.
# 409 / 1554 Time window done.
# 410 / 1554 Time window done.
# 411 / 1554 Time window done.
# 412 / 1554 Time window done.
# 413 / 1554 Time window done.
# 414 / 1554 Time window done.
# 415 / 1554 Time window done.
# 416 / 1554 Time window done.
# 417 / 1554 Time window done.
# 418 / 1554 Time window done.
# 419 / 1554 Time window done.
# 420 / 1554 Time window done.
# 421 / 1554 Time window done.
# 422 / 1554 Time window done.
# 423 / 1554 Time window done.
# 424 / 1554 Time window done.
# 425 / 1554 Time window done.
# 426 / 1554 Time window done.
# 427 / 1554 Time window done.
# 428 / 1554 Time window done.
# 429 / 1554 Time window done.
# 430 / 1554 Time window done.
# 431 / 1554 Time window done.
# 432 / 1554 Time window done.
# 433 / 1554 Time window done.
# 434 / 1554 Time window done.
# 435 / 1554 Time window done.
# 436 / 1554 Time window done.
# 437 / 1554 Time window done.
# 438 / 1554 Time window done.
# 439 / 1554 Time window done.
# 440 / 1554 Time window done.
# 441 / 1554 Time window done.
# 442 / 1554 Time window done.
# 443 / 1554 Time window done.
# 444 / 1554 Time window done.
# 445 / 1554 Time window done.
# 446 / 1554 Time window done.
# 447 / 1554 Time window done.
# 448 / 1554 Time window done.
# 449 / 1554 Time window done.
# 450 / 1554 Time window done.
# 451 / 1554 Time window done.
# 452 / 1554 Time window done.
# 453 / 1554 Time window done.
# 454 / 1554 Time window done.
# 455 / 1554 Time window done.
# 456 / 1554 Time window done.
# 457 / 1554 Time window done.
# 458 / 1554 Time window done.
# 459 / 1554 Time window done.
# 460 / 1554 Time window done.
# 461 / 1554 Time window done.
# 462 / 1554 Time window done.
# 463 / 1554 Time window done.
# 464 / 1554 Time window done.
# 465 / 1554 Time window done.
# 466 / 1554 Time window done.
# 467 / 1554 Time window done.
# 468 / 1554 Time window done.
# 469 / 1554 Time window done.
# 470 / 1554 Time window done.
# 471 / 1554 Time window done.
# 472 / 1554 Time window done.
# 473 / 1554 Time window done.
# 474 / 1554 Time window done.
# 475 / 1554 Time window done.
# 476 / 1554 Time window done.
# 477 / 1554 Time window done.
# 478 / 1554 Time window done.
# 479 / 1554 Time window done.
# 480 / 1554 Time window done.
# 481 / 1554 Time window done.
# 482 / 1554 Time window done.
# 483 / 1554 Time window done.
# 484 / 1554 Time window done.
# 485 / 1554 Time window done.
# 486 / 1554 Time window done.
# 487 / 1554 Time window done.
# 488 / 1554 Time window done.
# 489 / 1554 Time window done.
# 490 / 1554 Time window done.
# 491 / 1554 Time window done.
# 492 / 1554 Time window done.
# 493 / 1554 Time window done.
# 494 / 1554 Time window done.
# 495 / 1554 Time window done.
# 496 / 1554 Time window done.
# 497 / 1554 Time window done.
# 498 / 1554 Time window done.
# 499 / 1554 Time window done.
# 500 / 1554 Time window done.
# 501 / 1554 Time window done.
# 502 / 1554 Time window done.
# 503 / 1554 Time window done.
# 504 / 1554 Time window done.
# 505 / 1554 Time window done.
# 506 / 1554 Time window done.
# 507 / 1554 Time window done.
# 508 / 1554 Time window done.
# 509 / 1554 Time window done.
# 510 / 1554 Time window done.
# 511 / 1554 Time window done.
# 512 / 1554 Time window done.
# 513 / 1554 Time window done.
# 514 / 1554 Time window done.
# 515 / 1554 Time window done.
# 516 / 1554 Time window done.
# 517 / 1554 Time window done.
# 518 / 1554 Time window done.
# 519 / 1554 Time window done.
# 520 / 1554 Time window done.
# 521 / 1554 Time window done.
# 522 / 1554 Time window done.
# 523 / 1554 Time window done.
# 524 / 1554 Time window done.
# 525 / 1554 Time window done.
# 526 / 1554 Time window done.
# 527 / 1554 Time window done.
# 528 / 1554 Time window done.
# 529 / 1554 Time window done.
# 530 / 1554 Time window done.
# 531 / 1554 Time window done.
# 532 / 1554 Time window done.
# 533 / 1554 Time window done.
# 534 / 1554 Time window done.
# 535 / 1554 Time window done.
# 536 / 1554 Time window done.
# 537 / 1554 Time window done.
# 538 / 1554 Time window done.
# 539 / 1554 Time window done.
# 540 / 1554 Time window done.
# 541 / 1554 Time window done.
# 542 / 1554 Time window done.
# 543 / 1554 Time window done.
# 544 / 1554 Time window done.
# 545 / 1554 Time window done.
# 546 / 1554 Time window done.
# 547 / 1554 Time window done.
# 548 / 1554 Time window done.
# 549 / 1554 Time window done.
# 550 / 1554 Time window done.
# 551 / 1554 Time window done.
# 552 / 1554 Time window done.
# 553 / 1554 Time window done.
# 554 / 1554 Time window done.
# 555 / 1554 Time window done.
# 556 / 1554 Time window done.
# 557 / 1554 Time window done.
# 558 / 1554 Time window done.
# 559 / 1554 Time window done.
# 560 / 1554 Time window done.
# 561 / 1554 Time window done.
# 562 / 1554 Time window done.
# 563 / 1554 Time window done.
# 564 / 1554 Time window done.
# 565 / 1554 Time window done.
# 566 / 1554 Time window done.
# 567 / 1554 Time window done.
# 568 / 1554 Time window done.
# 569 / 1554 Time window done.
# 570 / 1554 Time window done.
# 571 / 1554 Time window done.
# 572 / 1554 Time window done.
# 573 / 1554 Time window done.
# 574 / 1554 Time window done.
# 575 / 1554 Time window done.
# 576 / 1554 Time window done.
# 577 / 1554 Time window done.
# 578 / 1554 Time window done.
# 579 / 1554 Time window done.
# 580 / 1554 Time window done.
# 581 / 1554 Time window done.
# 582 / 1554 Time window done.
# 583 / 1554 Time window done.
# 584 / 1554 Time window done.
# 585 / 1554 Time window done.
# 586 / 1554 Time window done.
# 587 / 1554 Time window done.
# 588 / 1554 Time window done.
# 589 / 1554 Time window done.
# 590 / 1554 Time window done.
# 591 / 1554 Time window done.
# 592 / 1554 Time window done.
# 593 / 1554 Time window done.
# 594 / 1554 Time window done.
# 595 / 1554 Time window done.
# 596 / 1554 Time window done.
# 597 / 1554 Time window done.
# 598 / 1554 Time window done.
# 599 / 1554 Time window done.
# 600 / 1554 Time window done.
# 601 / 1554 Time window done.
# 602 / 1554 Time window done.
# 603 / 1554 Time window done.
# 604 / 1554 Time window done.
# 605 / 1554 Time window done.
# 606 / 1554 Time window done.
# 607 / 1554 Time window done.
# 608 / 1554 Time window done.
# 609 / 1554 Time window done.
# 610 / 1554 Time window done.
# 611 / 1554 Time window done.
# 612 / 1554 Time window done.
# 613 / 1554 Time window done.
# 614 / 1554 Time window done.
# 615 / 1554 Time window done.
# 616 / 1554 Time window done.
# 617 / 1554 Time window done.
# 618 / 1554 Time window done.
# 619 / 1554 Time window done.
# 620 / 1554 Time window done.
# 621 / 1554 Time window done.
# 622 / 1554 Time window done.
# 623 / 1554 Time window done.
# 624 / 1554 Time window done.
# 625 / 1554 Time window done.
# 626 / 1554 Time window done.
# 627 / 1554 Time window done.
# 628 / 1554 Time window done.
# 629 / 1554 Time window done.
# 630 / 1554 Time window done.
# 631 / 1554 Time window done.
# 632 / 1554 Time window done.
# 633 / 1554 Time window done.
# 634 / 1554 Time window done.
# 635 / 1554 Time window done.
# 636 / 1554 Time window done.
# 637 / 1554 Time window done.
# 638 / 1554 Time window done.
# 639 / 1554 Time window done.
# 640 / 1554 Time window done.
# 641 / 1554 Time window done.
# 642 / 1554 Time window done.
# 643 / 1554 Time window done.
# 644 / 1554 Time window done.
# 645 / 1554 Time window done.
# 646 / 1554 Time window done.
# 647 / 1554 Time window done.
# 648 / 1554 Time window done.
# 649 / 1554 Time window done.
# 650 / 1554 Time window done.
# 651 / 1554 Time window done.
# 652 / 1554 Time window done.
# 653 / 1554 Time window done.
# 654 / 1554 Time window done.
# 655 / 1554 Time window done.
# 656 / 1554 Time window done.
# 657 / 1554 Time window done.
# 658 / 1554 Time window done.
# 659 / 1554 Time window done.
# 660 / 1554 Time window done.
# 661 / 1554 Time window done.
# 662 / 1554 Time window done.
# 663 / 1554 Time window done.
# 664 / 1554 Time window done.
# 665 / 1554 Time window done.
# 666 / 1554 Time window done.
# 667 / 1554 Time window done.
# 668 / 1554 Time window done.
# 669 / 1554 Time window done.
# 670 / 1554 Time window done.
# 671 / 1554 Time window done.
# 672 / 1554 Time window done.
# 673 / 1554 Time window done.
# 674 / 1554 Time window done.
# 675 / 1554 Time window done.
# 676 / 1554 Time window done.
# 677 / 1554 Time window done.
# 678 / 1554 Time window done.
# 679 / 1554 Time window done.
# 680 / 1554 Time window done.
# 681 / 1554 Time window done.
# 682 / 1554 Time window done.
# 683 / 1554 Time window done.
# 684 / 1554 Time window done.
# 685 / 1554 Time window done.
# 686 / 1554 Time window done.
# 687 / 1554 Time window done.
# 688 / 1554 Time window done.
# 689 / 1554 Time window done.
# 690 / 1554 Time window done.
# 691 / 1554 Time window done.
# 692 / 1554 Time window done.
# 693 / 1554 Time window done.
# 694 / 1554 Time window done.
# 695 / 1554 Time window done.
# 696 / 1554 Time window done.
# 697 / 1554 Time window done.
# 698 / 1554 Time window done.
# 699 / 1554 Time window done.
# 700 / 1554 Time window done.
# 701 / 1554 Time window done.
# 702 / 1554 Time window done.
# 703 / 1554 Time window done.
# 704 / 1554 Time window done.
# 705 / 1554 Time window done.
# 706 / 1554 Time window done.
# 707 / 1554 Time window done.
# 708 / 1554 Time window done.
# 709 / 1554 Time window done.
# 710 / 1554 Time window done.
# 711 / 1554 Time window done.
# 712 / 1554 Time window done.
# 713 / 1554 Time window done.
# 714 / 1554 Time window done.
# 715 / 1554 Time window done.
# 716 / 1554 Time window done.
# 717 / 1554 Time window done.
# 718 / 1554 Time window done.
# 719 / 1554 Time window done.
# 720 / 1554 Time window done.
# 721 / 1554 Time window done.
# 722 / 1554 Time window done.
# 723 / 1554 Time window done.
# 724 / 1554 Time window done.
# 725 / 1554 Time window done.
# 726 / 1554 Time window done.
# 727 / 1554 Time window done.
# 728 / 1554 Time window done.
# 729 / 1554 Time window done.
# 730 / 1554 Time window done.
# 731 / 1554 Time window done.
# 732 / 1554 Time window done.
# 733 / 1554 Time window done.
# 734 / 1554 Time window done.
# 735 / 1554 Time window done.
# 736 / 1554 Time window done.
# 737 / 1554 Time window done.
# 738 / 1554 Time window done.
# 739 / 1554 Time window done.
# 740 / 1554 Time window done.
# 741 / 1554 Time window done.
# 742 / 1554 Time window done.
# 743 / 1554 Time window done.
# 744 / 1554 Time window done.
# 745 / 1554 Time window done.
# 746 / 1554 Time window done.
# 747 / 1554 Time window done.
# 748 / 1554 Time window done.
# 749 / 1554 Time window done.
# 750 / 1554 Time window done.
# 751 / 1554 Time window done.
# 752 / 1554 Time window done.
# 753 / 1554 Time window done.
# 754 / 1554 Time window done.
# 755 / 1554 Time window done.
# 756 / 1554 Time window done.
# 757 / 1554 Time window done.
# 758 / 1554 Time window done.
# 759 / 1554 Time window done.
# 760 / 1554 Time window done.
# 761 / 1554 Time window done.
# 762 / 1554 Time window done.
# 763 / 1554 Time window done.
# 764 / 1554 Time window done.
# 765 / 1554 Time window done.
# 766 / 1554 Time window done.
# 767 / 1554 Time window done.
# 768 / 1554 Time window done.
# 769 / 1554 Time window done.
# 770 / 1554 Time window done.
# 771 / 1554 Time window done.
# 772 / 1554 Time window done.
# 773 / 1554 Time window done.
# 774 / 1554 Time window done.
# 775 / 1554 Time window done.
# 776 / 1554 Time window done.
# 777 / 1554 Time window done.
# 778 / 1554 Time window done.
# 779 / 1554 Time window done.
# 780 / 1554 Time window done.
# 781 / 1554 Time window done.
# 782 / 1554 Time window done.
# 783 / 1554 Time window done.
# 784 / 1554 Time window done.
# 785 / 1554 Time window done.
# 786 / 1554 Time window done.
# 787 / 1554 Time window done.
# 788 / 1554 Time window done.
# 789 / 1554 Time window done.
# 790 / 1554 Time window done.
# 791 / 1554 Time window done.
# 792 / 1554 Time window done.
# 793 / 1554 Time window done.
# 794 / 1554 Time window done.
# 795 / 1554 Time window done.
# 796 / 1554 Time window done.
# 797 / 1554 Time window done.
# 798 / 1554 Time window done.
# 799 / 1554 Time window done.
# 800 / 1554 Time window done.
# 801 / 1554 Time window done.
# 802 / 1554 Time window done.
# 803 / 1554 Time window done.
# 804 / 1554 Time window done.
# 805 / 1554 Time window done.
# 806 / 1554 Time window done.
# 807 / 1554 Time window done.
# 808 / 1554 Time window done.
# 809 / 1554 Time window done.
# 810 / 1554 Time window done.
# 811 / 1554 Time window done.
# 812 / 1554 Time window done.
# 813 / 1554 Time window done.
# 814 / 1554 Time window done.
# 815 / 1554 Time window done.
# 816 / 1554 Time window done.
# 817 / 1554 Time window done.
# 818 / 1554 Time window done.
# 819 / 1554 Time window done.
# 820 / 1554 Time window done.
# 821 / 1554 Time window done.
# 822 / 1554 Time window done.
# 823 / 1554 Time window done.
# 824 / 1554 Time window done.
# 825 / 1554 Time window done.
# 826 / 1554 Time window done.
# 827 / 1554 Time window done.
# 828 / 1554 Time window done.
# 829 / 1554 Time window done.
# 830 / 1554 Time window done.
# 831 / 1554 Time window done.
# 832 / 1554 Time window done.
# 833 / 1554 Time window done.
# 834 / 1554 Time window done.
# 835 / 1554 Time window done.
# 836 / 1554 Time window done.
# 837 / 1554 Time window done.
# 838 / 1554 Time window done.
# 839 / 1554 Time window done.
# 840 / 1554 Time window done.
# 841 / 1554 Time window done.
# 842 / 1554 Time window done.
# 843 / 1554 Time window done.
# 844 / 1554 Time window done.
# 845 / 1554 Time window done.
# 846 / 1554 Time window done.
# 847 / 1554 Time window done.
# 848 / 1554 Time window done.
# 849 / 1554 Time window done.
# 850 / 1554 Time window done.
# 851 / 1554 Time window done.
# 852 / 1554 Time window done.
# 853 / 1554 Time window done.
# 854 / 1554 Time window done.
# 855 / 1554 Time window done.
# 856 / 1554 Time window done.
# 857 / 1554 Time window done.
# 858 / 1554 Time window done.
# 859 / 1554 Time window done.
# 860 / 1554 Time window done.
# 861 / 1554 Time window done.
# 862 / 1554 Time window done.
# 863 / 1554 Time window done.
# 864 / 1554 Time window done.
# 865 / 1554 Time window done.
# 866 / 1554 Time window done.
# 867 / 1554 Time window done.
# 868 / 1554 Time window done.
# 869 / 1554 Time window done.
# 870 / 1554 Time window done.
# 871 / 1554 Time window done.
# 872 / 1554 Time window done.
# 873 / 1554 Time window done.
# 874 / 1554 Time window done.
# 875 / 1554 Time window done.
# 876 / 1554 Time window done.
# 877 / 1554 Time window done.
# 878 / 1554 Time window done.
# 879 / 1554 Time window done.
# 880 / 1554 Time window done.
# 881 / 1554 Time window done.
# 882 / 1554 Time window done.
# 883 / 1554 Time window done.
# 884 / 1554 Time window done.
# 885 / 1554 Time window done.
# 886 / 1554 Time window done.
# 887 / 1554 Time window done.
# 888 / 1554 Time window done.
# 889 / 1554 Time window done.
# 890 / 1554 Time window done.
# 891 / 1554 Time window done.
# 892 / 1554 Time window done.
# 893 / 1554 Time window done.
# 894 / 1554 Time window done.
# 895 / 1554 Time window done.
# 896 / 1554 Time window done.
# 897 / 1554 Time window done.
# 898 / 1554 Time window done.
# 899 / 1554 Time window done.
# 900 / 1554 Time window done.
# 901 / 1554 Time window done.
# 902 / 1554 Time window done.
# 903 / 1554 Time window done.
# 904 / 1554 Time window done.
# 905 / 1554 Time window done.
# 906 / 1554 Time window done.
# 907 / 1554 Time window done.
# 908 / 1554 Time window done.
# 909 / 1554 Time window done.
# 910 / 1554 Time window done.
# 911 / 1554 Time window done.
# 912 / 1554 Time window done.
# 913 / 1554 Time window done.
# 914 / 1554 Time window done.
# 915 / 1554 Time window done.
# 916 / 1554 Time window done.
# 917 / 1554 Time window done.
# 918 / 1554 Time window done.
# 919 / 1554 Time window done.
# 920 / 1554 Time window done.
# 921 / 1554 Time window done.
# 922 / 1554 Time window done.
# 923 / 1554 Time window done.
# 924 / 1554 Time window done.
# 925 / 1554 Time window done.
# 926 / 1554 Time window done.
# 927 / 1554 Time window done.
# 928 / 1554 Time window done.
# 929 / 1554 Time window done.
# 930 / 1554 Time window done.
# 931 / 1554 Time window done.
# 932 / 1554 Time window done.
# 933 / 1554 Time window done.
# 934 / 1554 Time window done.
# 935 / 1554 Time window done.
# 936 / 1554 Time window done.
# 937 / 1554 Time window done.
# 938 / 1554 Time window done.
# 939 / 1554 Time window done.
# 940 / 1554 Time window done.
# 941 / 1554 Time window done.
# 942 / 1554 Time window done.
# 943 / 1554 Time window done.
# 944 / 1554 Time window done.
# 945 / 1554 Time window done.
# 946 / 1554 Time window done.
# 947 / 1554 Time window done.
# 948 / 1554 Time window done.
# 949 / 1554 Time window done.
# 950 / 1554 Time window done.
# 951 / 1554 Time window done.
# 952 / 1554 Time window done.
# 953 / 1554 Time window done.
# 954 / 1554 Time window done.
# 955 / 1554 Time window done.
# 956 / 1554 Time window done.
# 957 / 1554 Time window done.
# 958 / 1554 Time window done.
# 959 / 1554 Time window done.
# 960 / 1554 Time window done.
# 961 / 1554 Time window done.
# 962 / 1554 Time window done.
# 963 / 1554 Time window done.
# 964 / 1554 Time window done.
# 965 / 1554 Time window done.
# 966 / 1554 Time window done.
# 967 / 1554 Time window done.
# 968 / 1554 Time window done.
# 969 / 1554 Time window done.
# 970 / 1554 Time window done.
# 971 / 1554 Time window done.
# 972 / 1554 Time window done.
# 973 / 1554 Time window done.
# 974 / 1554 Time window done.
# 975 / 1554 Time window done.
# 976 / 1554 Time window done.
# 977 / 1554 Time window done.
# 978 / 1554 Time window done.
# 979 / 1554 Time window done.
# 980 / 1554 Time window done.
# 981 / 1554 Time window done.
# 982 / 1554 Time window done.
# 983 / 1554 Time window done.
# 984 / 1554 Time window done.
# 985 / 1554 Time window done.
# 986 / 1554 Time window done.
# 987 / 1554 Time window done.
# 988 / 1554 Time window done.
# 989 / 1554 Time window done.
# 990 / 1554 Time window done.
# 991 / 1554 Time window done.
# 992 / 1554 Time window done.
# 993 / 1554 Time window done.
# 994 / 1554 Time window done.
# 995 / 1554 Time window done.
# 996 / 1554 Time window done.
# 997 / 1554 Time window done.
# 998 / 1554 Time window done.
# 999 / 1554 Time window done.
# 1000 / 1554 Time window done.
# 1001 / 1554 Time window done.
# 1002 / 1554 Time window done.
# 1003 / 1554 Time window done.
# 1004 / 1554 Time window done.
# 1005 / 1554 Time window done.
# 1006 / 1554 Time window done.
# 1007 / 1554 Time window done.
# 1008 / 1554 Time window done.
# 1009 / 1554 Time window done.
# 1010 / 1554 Time window done.
# 1011 / 1554 Time window done.
# 1012 / 1554 Time window done.
# 1013 / 1554 Time window done.
# 1014 / 1554 Time window done.
# 1015 / 1554 Time window done.
# 1016 / 1554 Time window done.
# 1017 / 1554 Time window done.
# 1018 / 1554 Time window done.
# 1019 / 1554 Time window done.
# 1020 / 1554 Time window done.
# 1021 / 1554 Time window done.
# 1022 / 1554 Time window done.
# 1023 / 1554 Time window done.
# 1024 / 1554 Time window done.
# 1025 / 1554 Time window done.
# 1026 / 1554 Time window done.
# 1027 / 1554 Time window done.
# 1028 / 1554 Time window done.
# 1029 / 1554 Time window done.
# 1030 / 1554 Time window done.
# 1031 / 1554 Time window done.
# 1032 / 1554 Time window done.
# 1033 / 1554 Time window done.
# 1034 / 1554 Time window done.
# 1035 / 1554 Time window done.
# 1036 / 1554 Time window done.
# 1037 / 1554 Time window done.
# 1038 / 1554 Time window done.
# 1039 / 1554 Time window done.
# 1040 / 1554 Time window done.
# 1041 / 1554 Time window done.
# 1042 / 1554 Time window done.
# 1043 / 1554 Time window done.
# 1044 / 1554 Time window done.
# 1045 / 1554 Time window done.
# 1046 / 1554 Time window done.
# 1047 / 1554 Time window done.
# 1048 / 1554 Time window done.
# 1049 / 1554 Time window done.
# 1050 / 1554 Time window done.
# 1051 / 1554 Time window done.
# 1052 / 1554 Time window done.
# 1053 / 1554 Time window done.
# 1054 / 1554 Time window done.
# 1055 / 1554 Time window done.
# 1056 / 1554 Time window done.
# 1057 / 1554 Time window done.
# 1058 / 1554 Time window done.
# 1059 / 1554 Time window done.
# 1060 / 1554 Time window done.
# 1061 / 1554 Time window done.
# 1062 / 1554 Time window done.
# 1063 / 1554 Time window done.
# 1064 / 1554 Time window done.
# 1065 / 1554 Time window done.
# 1066 / 1554 Time window done.
# 1067 / 1554 Time window done.
# 1068 / 1554 Time window done.
# 1069 / 1554 Time window done.
# 1070 / 1554 Time window done.
# 1071 / 1554 Time window done.
# 1072 / 1554 Time window done.
# 1073 / 1554 Time window done.
# 1074 / 1554 Time window done.
# 1075 / 1554 Time window done.
# 1076 / 1554 Time window done.
# 1077 / 1554 Time window done.
# 1078 / 1554 Time window done.
# 1079 / 1554 Time window done.
# 1080 / 1554 Time window done.
# 1081 / 1554 Time window done.
# 1082 / 1554 Time window done.
# 1083 / 1554 Time window done.
# 1084 / 1554 Time window done.
# 1085 / 1554 Time window done.
# 1086 / 1554 Time window done.
# 1087 / 1554 Time window done.
# 1088 / 1554 Time window done.
# 1089 / 1554 Time window done.
# 1090 / 1554 Time window done.
# 1091 / 1554 Time window done.
# 1092 / 1554 Time window done.
# 1093 / 1554 Time window done.
# 1094 / 1554 Time window done.
# 1095 / 1554 Time window done.
# 1096 / 1554 Time window done.
# 1097 / 1554 Time window done.
# 1098 / 1554 Time window done.
# 1099 / 1554 Time window done.
# 1100 / 1554 Time window done.
# 1101 / 1554 Time window done.
# 1102 / 1554 Time window done.
# 1103 / 1554 Time window done.
# 1104 / 1554 Time window done.
# 1105 / 1554 Time window done.
# 1106 / 1554 Time window done.
# 1107 / 1554 Time window done.
# 1108 / 1554 Time window done.
# 1109 / 1554 Time window done.
# 1110 / 1554 Time window done.
# 1111 / 1554 Time window done.
# 1112 / 1554 Time window done.
# 1113 / 1554 Time window done.
# 1114 / 1554 Time window done.
# 1115 / 1554 Time window done.
# 1116 / 1554 Time window done.
# 1117 / 1554 Time window done.
# 1118 / 1554 Time window done.
# 1119 / 1554 Time window done.
# 1120 / 1554 Time window done.
# 1121 / 1554 Time window done.
# 1122 / 1554 Time window done.
# 1123 / 1554 Time window done.
# 1124 / 1554 Time window done.
# 1125 / 1554 Time window done.
# 1126 / 1554 Time window done.
# 1127 / 1554 Time window done.
# 1128 / 1554 Time window done.
# 1129 / 1554 Time window done.
# 1130 / 1554 Time window done.
# 1131 / 1554 Time window done.
# 1132 / 1554 Time window done.
# 1133 / 1554 Time window done.
# 1134 / 1554 Time window done.
# 1135 / 1554 Time window done.
# 1136 / 1554 Time window done.
# 1137 / 1554 Time window done.
# 1138 / 1554 Time window done.
# 1139 / 1554 Time window done.
# 1140 / 1554 Time window done.
# 1141 / 1554 Time window done.
# 1142 / 1554 Time window done.
# 1143 / 1554 Time window done.
# 1144 / 1554 Time window done.
# 1145 / 1554 Time window done.
# 1146 / 1554 Time window done.
# 1147 / 1554 Time window done.
# 1148 / 1554 Time window done.
# 1149 / 1554 Time window done.
# 1150 / 1554 Time window done.
# 1151 / 1554 Time window done.
# 1152 / 1554 Time window done.
# 1153 / 1554 Time window done.
# 1154 / 1554 Time window done.
# 1155 / 1554 Time window done.
# 1156 / 1554 Time window done.
# 1157 / 1554 Time window done.
# 1158 / 1554 Time window done.
# 1159 / 1554 Time window done.
# 1160 / 1554 Time window done.
# 1161 / 1554 Time window done.
# 1162 / 1554 Time window done.
# 1163 / 1554 Time window done.
# 1164 / 1554 Time window done.
# 1165 / 1554 Time window done.
# 1166 / 1554 Time window done.
# 1167 / 1554 Time window done.
# 1168 / 1554 Time window done.
# 1169 / 1554 Time window done.
# 1170 / 1554 Time window done.
# 1171 / 1554 Time window done.
# 1172 / 1554 Time window done.
# 1173 / 1554 Time window done.
# 1174 / 1554 Time window done.
# 1175 / 1554 Time window done.
# 1176 / 1554 Time window done.
# 1177 / 1554 Time window done.
# 1178 / 1554 Time window done.
# 1179 / 1554 Time window done.
# 1180 / 1554 Time window done.
# 1181 / 1554 Time window done.
# 1182 / 1554 Time window done.
# 1183 / 1554 Time window done.
# 1184 / 1554 Time window done.
# 1185 / 1554 Time window done.
# 1186 / 1554 Time window done.
# 1187 / 1554 Time window done.
# 1188 / 1554 Time window done.
# 1189 / 1554 Time window done.
# 1190 / 1554 Time window done.
# 1191 / 1554 Time window done.
# 1192 / 1554 Time window done.
# 1193 / 1554 Time window done.
# 1194 / 1554 Time window done.
# 1195 / 1554 Time window done.
# 1196 / 1554 Time window done.
# 1197 / 1554 Time window done.
# 1198 / 1554 Time window done.
# 1199 / 1554 Time window done.
# 1200 / 1554 Time window done.
# 1201 / 1554 Time window done.
# 1202 / 1554 Time window done.
# 1203 / 1554 Time window done.
# 1204 / 1554 Time window done.
# 1205 / 1554 Time window done.
# 1206 / 1554 Time window done.
# 1207 / 1554 Time window done.
# 1208 / 1554 Time window done.
# 1209 / 1554 Time window done.
# 1210 / 1554 Time window done.
# 1211 / 1554 Time window done.
# 1212 / 1554 Time window done.
# 1213 / 1554 Time window done.
# 1214 / 1554 Time window done.
# 1215 / 1554 Time window done.
# 1216 / 1554 Time window done.
# 1217 / 1554 Time window done.
# 1218 / 1554 Time window done.
# 1219 / 1554 Time window done.
# 1220 / 1554 Time window done.
# 1221 / 1554 Time window done.
# 1222 / 1554 Time window done.
# 1223 / 1554 Time window done.
# 1224 / 1554 Time window done.
# 1225 / 1554 Time window done.
# 1226 / 1554 Time window done.
# 1227 / 1554 Time window done.
# 1228 / 1554 Time window done.
# 1229 / 1554 Time window done.
# 1230 / 1554 Time window done.
# 1231 / 1554 Time window done.
# 1232 / 1554 Time window done.
# 1233 / 1554 Time window done.
# 1234 / 1554 Time window done.
# 1235 / 1554 Time window done.
# 1236 / 1554 Time window done.
# 1237 / 1554 Time window done.
# 1238 / 1554 Time window done.
# 1239 / 1554 Time window done.
# 1240 / 1554 Time window done.
# 1241 / 1554 Time window done.
# 1242 / 1554 Time window done.
# 1243 / 1554 Time window done.
# 1244 / 1554 Time window done.
# 1245 / 1554 Time window done.
# 1246 / 1554 Time window done.
# 1247 / 1554 Time window done.
# 1248 / 1554 Time window done.
# 1249 / 1554 Time window done.
# 1250 / 1554 Time window done.
# 1251 / 1554 Time window done.
# 1252 / 1554 Time window done.
# 1253 / 1554 Time window done.
# 1254 / 1554 Time window done.
# 1255 / 1554 Time window done.
# 1256 / 1554 Time window done.
# 1257 / 1554 Time window done.
# 1258 / 1554 Time window done.
# 1259 / 1554 Time window done.
# 1260 / 1554 Time window done.
# 1261 / 1554 Time window done.
# 1262 / 1554 Time window done.
# 1263 / 1554 Time window done.
# 1264 / 1554 Time window done.
# 1265 / 1554 Time window done.
# 1266 / 1554 Time window done.
# 1267 / 1554 Time window done.
# 1268 / 1554 Time window done.
# 1269 / 1554 Time window done.
# 1270 / 1554 Time window done.
# 1271 / 1554 Time window done.
# 1272 / 1554 Time window done.
# 1273 / 1554 Time window done.
# 1274 / 1554 Time window done.
# 1275 / 1554 Time window done.
# 1276 / 1554 Time window done.
# 1277 / 1554 Time window done.
# 1278 / 1554 Time window done.
# 1279 / 1554 Time window done.
# 1280 / 1554 Time window done.
# 1281 / 1554 Time window done.
# 1282 / 1554 Time window done.
# 1283 / 1554 Time window done.
# 1284 / 1554 Time window done.
# 1285 / 1554 Time window done.
# 1286 / 1554 Time window done.
# 1287 / 1554 Time window done.
# 1288 / 1554 Time window done.
# 1289 / 1554 Time window done.
# 1290 / 1554 Time window done.
# 1291 / 1554 Time window done.
# 1292 / 1554 Time window done.
# 1293 / 1554 Time window done.
# 1294 / 1554 Time window done.
# 1295 / 1554 Time window done.
# 1296 / 1554 Time window done.
# 1297 / 1554 Time window done.
# 1298 / 1554 Time window done.
# 1299 / 1554 Time window done.
# 1300 / 1554 Time window done.
# 1301 / 1554 Time window done.
# 1302 / 1554 Time window done.
# 1303 / 1554 Time window done.
# 1304 / 1554 Time window done.
# 1305 / 1554 Time window done.
# 1306 / 1554 Time window done.
# 1307 / 1554 Time window done.
# 1308 / 1554 Time window done.
# 1309 / 1554 Time window done.
# 1310 / 1554 Time window done.
# 1311 / 1554 Time window done.
# 1312 / 1554 Time window done.
# 1313 / 1554 Time window done.
# 1314 / 1554 Time window done.
# 1315 / 1554 Time window done.
# 1316 / 1554 Time window done.
# 1317 / 1554 Time window done.
# 1318 / 1554 Time window done.
# 1319 / 1554 Time window done.
# 1320 / 1554 Time window done.
# 1321 / 1554 Time window done.
# 1322 / 1554 Time window done.
# 1323 / 1554 Time window done.
# 1324 / 1554 Time window done.
# 1325 / 1554 Time window done.
# 1326 / 1554 Time window done.
# 1327 / 1554 Time window done.
# 1328 / 1554 Time window done.
# 1329 / 1554 Time window done.
# 1330 / 1554 Time window done.
# 1331 / 1554 Time window done.
# 1332 / 1554 Time window done.
# 1333 / 1554 Time window done.
# 1334 / 1554 Time window done.
# 1335 / 1554 Time window done.
# 1336 / 1554 Time window done.
# 1337 / 1554 Time window done.
# 1338 / 1554 Time window done.
# 1339 / 1554 Time window done.
# 1340 / 1554 Time window done.
# 1341 / 1554 Time window done.
# 1342 / 1554 Time window done.
# 1343 / 1554 Time window done.
# 1344 / 1554 Time window done.
# 1345 / 1554 Time window done.
# 1346 / 1554 Time window done.
# 1347 / 1554 Time window done.
# 1348 / 1554 Time window done.
# 1349 / 1554 Time window done.
# 1350 / 1554 Time window done.
# 1351 / 1554 Time window done.
# 1352 / 1554 Time window done.
# 1353 / 1554 Time window done.
# 1354 / 1554 Time window done.
# 1355 / 1554 Time window done.
# 1356 / 1554 Time window done.
# 1357 / 1554 Time window done.
# 1358 / 1554 Time window done.
# 1359 / 1554 Time window done.
# 1360 / 1554 Time window done.
# 1361 / 1554 Time window done.
# 1362 / 1554 Time window done.
# 1363 / 1554 Time window done.
# 1364 / 1554 Time window done.
# 1365 / 1554 Time window done.
# 1366 / 1554 Time window done.
# 1367 / 1554 Time window done.
# 1368 / 1554 Time window done.
# 1369 / 1554 Time window done.
# 1370 / 1554 Time window done.
# 1371 / 1554 Time window done.
# 1372 / 1554 Time window done.
# 1373 / 1554 Time window done.
# 1374 / 1554 Time window done.
# 1375 / 1554 Time window done.
# 1376 / 1554 Time window done.
# 1377 / 1554 Time window done.
# 1378 / 1554 Time window done.
# 1379 / 1554 Time window done.
# 1380 / 1554 Time window done.
# 1381 / 1554 Time window done.
# 1382 / 1554 Time window done.
# 1383 / 1554 Time window done.
# 1384 / 1554 Time window done.
# 1385 / 1554 Time window done.
# 1386 / 1554 Time window done.
# 1387 / 1554 Time window done.
# 1388 / 1554 Time window done.
# 1389 / 1554 Time window done.
# 1390 / 1554 Time window done.
# 1391 / 1554 Time window done.
# 1392 / 1554 Time window done.
# 1393 / 1554 Time window done.
# 1394 / 1554 Time window done.
# 1395 / 1554 Time window done.
# 1396 / 1554 Time window done.
# 1397 / 1554 Time window done.
# 1398 / 1554 Time window done.
# 1399 / 1554 Time window done.
# 1400 / 1554 Time window done.
# 1401 / 1554 Time window done.
# 1402 / 1554 Time window done.
# 1403 / 1554 Time window done.
# 1404 / 1554 Time window done.
# 1405 / 1554 Time window done.
# 1406 / 1554 Time window done.
# 1407 / 1554 Time window done.
# 1408 / 1554 Time window done.
# 1409 / 1554 Time window done.
# 1410 / 1554 Time window done.
# 1411 / 1554 Time window done.
# 1412 / 1554 Time window done.
# 1413 / 1554 Time window done.
# 1414 / 1554 Time window done.
# 1415 / 1554 Time window done.
# 1416 / 1554 Time window done.
# 1417 / 1554 Time window done.
# 1418 / 1554 Time window done.
# 1419 / 1554 Time window done.
# 1420 / 1554 Time window done.
# 1421 / 1554 Time window done.
# 1422 / 1554 Time window done.
# 1423 / 1554 Time window done.
# 1424 / 1554 Time window done.
# 1425 / 1554 Time window done.
# 1426 / 1554 Time window done.
# 1427 / 1554 Time window done.
# 1428 / 1554 Time window done.
# 1429 / 1554 Time window done.
# 1430 / 1554 Time window done.
# 1431 / 1554 Time window done.
# 1432 / 1554 Time window done.
# 1433 / 1554 Time window done.
# 1434 / 1554 Time window done.
# 1435 / 1554 Time window done.
# 1436 / 1554 Time window done.
# 1437 / 1554 Time window done.
# 1438 / 1554 Time window done.
# 1439 / 1554 Time window done.
# 1440 / 1554 Time window done.
# 1441 / 1554 Time window done.
# 1442 / 1554 Time window done.
# 1443 / 1554 Time window done.
# 1444 / 1554 Time window done.
# 1445 / 1554 Time window done.
# 1446 / 1554 Time window done.
# 1447 / 1554 Time window done.
# 1448 / 1554 Time window done.
# 1449 / 1554 Time window done.
# 1450 / 1554 Time window done.
# 1451 / 1554 Time window done.
# 1452 / 1554 Time window done.
# 1453 / 1554 Time window done.
# 1454 / 1554 Time window done.
# 1455 / 1554 Time window done.
# 1456 / 1554 Time window done.
# 1457 / 1554 Time window done.
# 1458 / 1554 Time window done.
# 1459 / 1554 Time window done.
# 1460 / 1554 Time window done.
# 1461 / 1554 Time window done.
# 1462 / 1554 Time window done.
# 1463 / 1554 Time window done.
# 1464 / 1554 Time window done.
# 1465 / 1554 Time window done.
# 1466 / 1554 Time window done.
# 1467 / 1554 Time window done.
# 1468 / 1554 Time window done.
# 1469 / 1554 Time window done.
# 1470 / 1554 Time window done.
# 1471 / 1554 Time window done.
# 1472 / 1554 Time window done.
# 1473 / 1554 Time window done.
# 1474 / 1554 Time window done.
# 1475 / 1554 Time window done.
# 1476 / 1554 Time window done.
# 1477 / 1554 Time window done.
# 1478 / 1554 Time window done.
# 1479 / 1554 Time window done.
# 1480 / 1554 Time window done.
# 1481 / 1554 Time window done.
# 1482 / 1554 Time window done.
# 1483 / 1554 Time window done.
# 1484 / 1554 Time window done.
# 1485 / 1554 Time window done.
# 1486 / 1554 Time window done.
# 1487 / 1554 Time window done.
# 1488 / 1554 Time window done.
# 1489 / 1554 Time window done.
# 1490 / 1554 Time window done.
# 1491 / 1554 Time window done.
# 1492 / 1554 Time window done.
# 1493 / 1554 Time window done.
# 1494 / 1554 Time window done.
# 1495 / 1554 Time window done.
# 1496 / 1554 Time window done.
# 1497 / 1554 Time window done.
# 1498 / 1554 Time window done.
# 1499 / 1554 Time window done.
# 1500 / 1554 Time window done.
# 1501 / 1554 Time window done.
# 1502 / 1554 Time window done.
# 1503 / 1554 Time window done.
# 1504 / 1554 Time window done.
# 1505 / 1554 Time window done.
# 1506 / 1554 Time window done.
# 1507 / 1554 Time window done.
# 1508 / 1554 Time window done.
# 1509 / 1554 Time window done.
# 1510 / 1554 Time window done.
# 1511 / 1554 Time window done.
# 1512 / 1554 Time window done.
# 1513 / 1554 Time window done.
# 1514 / 1554 Time window done.
# 1515 / 1554 Time window done.
# 1516 / 1554 Time window done.
# 1517 / 1554 Time window done.
# 1518 / 1554 Time window done.
# 1519 / 1554 Time window done.
# 1520 / 1554 Time window done.
# 1521 / 1554 Time window done.
# 1522 / 1554 Time window done.
# 1523 / 1554 Time window done.
# 1524 / 1554 Time window done.
# 1525 / 1554 Time window done.
# 1526 / 1554 Time window done.
# 1527 / 1554 Time window done.
# 1528 / 1554 Time window done.
# 1529 / 1554 Time window done.
# 1530 / 1554 Time window done.
# 1531 / 1554 Time window done.
# 1532 / 1554 Time window done.
# 1533 / 1554 Time window done.
# 1534 / 1554 Time window done.
# 1535 / 1554 Time window done.
# 1536 / 1554 Time window done.
# 1537 / 1554 Time window done.
# 1538 / 1554 Time window done.
# 1539 / 1554 Time window done.
# 1540 / 1554 Time window done.
# 1541 / 1554 Time window done.
# 1542 / 1554 Time window done.
# 1543 / 1554 Time window done.
# 1544 / 1554 Time window done.
# 1545 / 1554 Time window done.
# 1546 / 1554 Time window done.
# 1547 / 1554 Time window done.
# 1548 / 1554 Time window done.
# 1549 / 1554 Time window done.
# 1550 / 1554 Time window done.
# 1551 / 1554 Time window done.
# Whole dataset done.

# %%
print(f"AUC: {roc_auc_score(darpa_results.label, darpa_results.scores):.3f}")
print(f"Total time: {anograph_time:.2f}s")
# Out:
# AUC: 0.835
# Total time: 53.66s

# %% [markdown]
# ## AnoEdge Global

# %%
rows = 2
buckets = 32
decay_factor = 0.9
anoedge = AnoEdgeGlobal(rows, buckets, decay_factor)

# %%
def evaluate_edge(stream, model, n_wait=100000):
    """
    Evaluate a streaming model on a given data stream for edge anomaly detection.

    Parameters
    ----------
    stream : iterable
        A data stream where each element is a tuple (x, y), where x is the input data for the model
        to learn, and y is the label or additional information.
    model :
        The streaming model to evaluate.
    n_wait : int
        The number of observations to wait before printing progress information. Default is 100,000.

    Returns
    -------
    results : pandas.DataFrame
        A DataFrame containing evaluation results, including scores for each time window.
    """
    # Initialize results DataFrame with DARPA AnoEdge labels
    results = darpa_label_anoedge.copy()
    results['scores'] = 0.0
    
    # Iterate over the data stream
    for i, (x,y) in enumerate(stream):
        # Update the model with the current data point
        model.learn_one(x)
        
        # Score the current data point and update results
        results.loc[i, 'scores'] = model.score_one(x)
        
        if i % n_wait == 0 and i > 0:
            # Print progress information
            print(f"{i} observations done")

    return results

# %%
anoedge_start = time.time()
darpa_results_edge = evaluate_edge(stream=iter_pandas(X=darpa, y=darpa_label_anoedge),
                       model=anoedge)
anoedge_time = time.time() - anoedge_start
# Out:
# 100000 observations done
# 200000 observations done
# 300000 observations done
# 400000 observations done
# 500000 observations done
# 600000 observations done
# 700000 observations done
# 800000 observations done
# 900000 observations done
# 1000000 observations done
# 1100000 observations done
# 1200000 observations done
# 1300000 observations done
# 1400000 observations done
# 1500000 observations done
# 1600000 observations done
# 1700000 observations done
# 1800000 observations done
# 1900000 observations done
# 2000000 observations done
# 2100000 observations done
# 2200000 observations done
# 2300000 observations done
# 2400000 observations done
# 2500000 observations done
# 2600000 observations done
# 2700000 observations done
# 2800000 observations done
# 2900000 observations done
# 3000000 observations done
# 3100000 observations done
# 3200000 observations done
# 3300000 observations done
# 3400000 observations done
# 3500000 observations done
# 3600000 observations done
# 3700000 observations done
# 3800000 observations done
# 3900000 observations done
# 4000000 observations done
# 4100000 observations done
# 4200000 observations done
# 4300000 observations done
# 4400000 observations done
# 4500000 observations done

# %%
print(f"AUC: {roc_auc_score(darpa_results_edge.label, darpa_results_edge.scores):.3f}")
print(f"Total time: {anoedge_time:.2f}s")
# Out:
# AUC: 0.969
# Total time: 5684.66s

# %% [markdown]
# # ISCX Dataset

# %%
iscx = pd.read_csv('./data/ISCX/Data.csv', header=None, names=['src', 'dst', 'time'])
iscx_label_anograph = pd.read_csv('./data/ISCX/Label.csv', header=None, names=['label'])
iscx_label_anoedge = pd.read_csv('./data/ISCX/Label.csv', header=None, names=['label'])

# %% [markdown]
# ## AnoGraph

# %% [markdown]
# ### Hyperparameters

# %%
time_window = 60
edge_threshold = 100 
rows = 2
buckets = 32
anograph = Anograph(time_window, edge_threshold, rows, buckets)

# %% [markdown]
# ### Preprocessing labels for AnoGraph

# %%
iscx_label_anograph['time'] = (iscx['time'].copy() / time_window).astype(int)
iscx_label_anograph = iscx_label_anograph.groupby('time').sum()
iscx_label_anograph['label'] = iscx_label_anograph['label'].apply(lambda x: 1 if x >= edge_threshold else 0)

# %% [markdown]
# ### Define AnoGraph evaluate function

# %%
def evaluate(stream, model, time_window):
    """
    Evaluate a model on a given data stream.

    Parameters
    ----------
    stream : iterable
        A data stream where each element is a tuple (x, _), where x is a dictionary containing
        data for the model to learn, and _ is a placeholder for any additional information.
    model :
        The streaming model to evaluate.
    time_window : int
        Time window for processing data.

    Returns
    -------
    results : pandas.DataFrame
        A DataFrame containing evaluation results, including scores for each time window.
    """
    # Create a copy of the ISCX label DataFrame to store results
    results = iscx_label_anograph.copy()
    results['scores'] = 0.0
    cur_time = 0
    
    # Iterate over the stream data
    for i, (x,_) in enumerate(stream):
        t = x['time']
        
        # Update the model with the current data point
        model.learn_one(x)
        
        # Check if the time has crossed a new time window
        if t // time_window != cur_time:
            
            # Predict the anomaly score for the current time window
            results.loc[cur_time, 'scores'] = model.get_score()
            print(f"{cur_time} / 2752 Time window done.")
            cur_time = t // time_window
            
    # Update results for the last time window
    results.loc[cur_time, 'scores'] = model.get_score()
    print(f"Whole dataset done.")

    return results

# %%
anograph_start = time.time()
iscx_results = evaluate(stream=iter_pandas(X=iscx),
                       model=anograph, time_window=time_window)
anograph_time = time.time() - anograph_start
# Out:
# 0 / 2752 Time window done.
# 1 / 2752 Time window done.
# 2 / 2752 Time window done.
# 3 / 2752 Time window done.
# 4 / 2752 Time window done.
# 5 / 2752 Time window done.
# 6 / 2752 Time window done.
# 7 / 2752 Time window done.
# 8 / 2752 Time window done.
# 9 / 2752 Time window done.
# 10 / 2752 Time window done.
# 11 / 2752 Time window done.
# 12 / 2752 Time window done.
# 13 / 2752 Time window done.
# 14 / 2752 Time window done.
# 15 / 2752 Time window done.
# 16 / 2752 Time window done.
# 17 / 2752 Time window done.
# 18 / 2752 Time window done.
# 19 / 2752 Time window done.
# 20 / 2752 Time window done.
# 21 / 2752 Time window done.
# 22 / 2752 Time window done.
# 23 / 2752 Time window done.
# 24 / 2752 Time window done.
# 25 / 2752 Time window done.
# 26 / 2752 Time window done.
# 27 / 2752 Time window done.
# 28 / 2752 Time window done.
# 29 / 2752 Time window done.
# 30 / 2752 Time window done.
# 31 / 2752 Time window done.
# 32 / 2752 Time window done.
# 33 / 2752 Time window done.
# 34 / 2752 Time window done.
# 35 / 2752 Time window done.
# 36 / 2752 Time window done.
# 37 / 2752 Time window done.
# 38 / 2752 Time window done.
# 39 / 2752 Time window done.
# 40 / 2752 Time window done.
# 41 / 2752 Time window done.
# 42 / 2752 Time window done.
# 43 / 2752 Time window done.
# 44 / 2752 Time window done.
# 45 / 2752 Time window done.
# 46 / 2752 Time window done.
# 47 / 2752 Time window done.
# 48 / 2752 Time window done.
# 49 / 2752 Time window done.
# 50 / 2752 Time window done.
# 51 / 2752 Time window done.
# 52 / 2752 Time window done.
# 53 / 2752 Time window done.
# 54 / 2752 Time window done.
# 55 / 2752 Time window done.
# 56 / 2752 Time window done.
# 57 / 2752 Time window done.
# 58 / 2752 Time window done.
# 59 / 2752 Time window done.
# 60 / 2752 Time window done.
# 61 / 2752 Time window done.
# 62 / 2752 Time window done.
# 63 / 2752 Time window done.
# 64 / 2752 Time window done.
# 65 / 2752 Time window done.
# 66 / 2752 Time window done.
# 67 / 2752 Time window done.
# 68 / 2752 Time window done.
# 69 / 2752 Time window done.
# 70 / 2752 Time window done.
# 71 / 2752 Time window done.
# 72 / 2752 Time window done.
# 73 / 2752 Time window done.
# 74 / 2752 Time window done.
# 75 / 2752 Time window done.
# 76 / 2752 Time window done.
# 77 / 2752 Time window done.
# 78 / 2752 Time window done.
# 79 / 2752 Time window done.
# 80 / 2752 Time window done.
# 81 / 2752 Time window done.
# 82 / 2752 Time window done.
# 83 / 2752 Time window done.
# 84 / 2752 Time window done.
# 85 / 2752 Time window done.
# 86 / 2752 Time window done.
# 87 / 2752 Time window done.
# 88 / 2752 Time window done.
# 89 / 2752 Time window done.
# 90 / 2752 Time window done.
# 91 / 2752 Time window done.
# 92 / 2752 Time window done.
# 93 / 2752 Time window done.
# 94 / 2752 Time window done.
# 95 / 2752 Time window done.
# 96 / 2752 Time window done.
# 97 / 2752 Time window done.
# 98 / 2752 Time window done.
# 99 / 2752 Time window done.
# 100 / 2752 Time window done.
# 101 / 2752 Time window done.
# 102 / 2752 Time window done.
# 103 / 2752 Time window done.
# 104 / 2752 Time window done.
# 105 / 2752 Time window done.
# 106 / 2752 Time window done.
# 107 / 2752 Time window done.
# 108 / 2752 Time window done.
# 109 / 2752 Time window done.
# 110 / 2752 Time window done.
# 111 / 2752 Time window done.
# 112 / 2752 Time window done.
# 113 / 2752 Time window done.
# 114 / 2752 Time window done.
# 115 / 2752 Time window done.
# 116 / 2752 Time window done.
# 117 / 2752 Time window done.
# 118 / 2752 Time window done.
# 119 / 2752 Time window done.
# 120 / 2752 Time window done.
# 121 / 2752 Time window done.
# 122 / 2752 Time window done.
# 123 / 2752 Time window done.
# 124 / 2752 Time window done.
# 125 / 2752 Time window done.
# 126 / 2752 Time window done.
# 127 / 2752 Time window done.
# 128 / 2752 Time window done.
# 129 / 2752 Time window done.
# 130 / 2752 Time window done.
# 131 / 2752 Time window done.
# 132 / 2752 Time window done.
# 133 / 2752 Time window done.
# 134 / 2752 Time window done.
# 135 / 2752 Time window done.
# 136 / 2752 Time window done.
# 137 / 2752 Time window done.
# 138 / 2752 Time window done.
# 139 / 2752 Time window done.
# 140 / 2752 Time window done.
# 141 / 2752 Time window done.
# 142 / 2752 Time window done.
# 143 / 2752 Time window done.
# 144 / 2752 Time window done.
# 145 / 2752 Time window done.
# 146 / 2752 Time window done.
# 147 / 2752 Time window done.
# 148 / 2752 Time window done.
# 149 / 2752 Time window done.
# 150 / 2752 Time window done.
# 151 / 2752 Time window done.
# 152 / 2752 Time window done.
# 153 / 2752 Time window done.
# 154 / 2752 Time window done.
# 155 / 2752 Time window done.
# 156 / 2752 Time window done.
# 157 / 2752 Time window done.
# 158 / 2752 Time window done.
# 159 / 2752 Time window done.
# 160 / 2752 Time window done.
# 161 / 2752 Time window done.
# 162 / 2752 Time window done.
# 163 / 2752 Time window done.
# 164 / 2752 Time window done.
# 165 / 2752 Time window done.
# 166 / 2752 Time window done.
# 167 / 2752 Time window done.
# 168 / 2752 Time window done.
# 169 / 2752 Time window done.
# 170 / 2752 Time window done.
# 171 / 2752 Time window done.
# 172 / 2752 Time window done.
# 173 / 2752 Time window done.
# 174 / 2752 Time window done.
# 175 / 2752 Time window done.
# 176 / 2752 Time window done.
# 177 / 2752 Time window done.
# 178 / 2752 Time window done.
# 179 / 2752 Time window done.
# 180 / 2752 Time window done.
# 181 / 2752 Time window done.
# 182 / 2752 Time window done.
# 183 / 2752 Time window done.
# 184 / 2752 Time window done.
# 185 / 2752 Time window done.
# 186 / 2752 Time window done.
# 187 / 2752 Time window done.
# 188 / 2752 Time window done.
# 189 / 2752 Time window done.
# 190 / 2752 Time window done.
# 191 / 2752 Time window done.
# 192 / 2752 Time window done.
# 193 / 2752 Time window done.
# 194 / 2752 Time window done.
# 195 / 2752 Time window done.
# 196 / 2752 Time window done.
# 197 / 2752 Time window done.
# 198 / 2752 Time window done.
# 199 / 2752 Time window done.
# 200 / 2752 Time window done.
# 201 / 2752 Time window done.
# 202 / 2752 Time window done.
# 203 / 2752 Time window done.
# 204 / 2752 Time window done.
# 205 / 2752 Time window done.
# 206 / 2752 Time window done.
# 207 / 2752 Time window done.
# 208 / 2752 Time window done.
# 209 / 2752 Time window done.
# 210 / 2752 Time window done.
# 211 / 2752 Time window done.
# 212 / 2752 Time window done.
# 213 / 2752 Time window done.
# 214 / 2752 Time window done.
# 215 / 2752 Time window done.
# 216 / 2752 Time window done.
# 217 / 2752 Time window done.
# 218 / 2752 Time window done.
# 219 / 2752 Time window done.
# 220 / 2752 Time window done.
# 221 / 2752 Time window done.
# 222 / 2752 Time window done.
# 223 / 2752 Time window done.
# 224 / 2752 Time window done.
# 225 / 2752 Time window done.
# 226 / 2752 Time window done.
# 227 / 2752 Time window done.
# 228 / 2752 Time window done.
# 229 / 2752 Time window done.
# 230 / 2752 Time window done.
# 231 / 2752 Time window done.
# 232 / 2752 Time window done.
# 233 / 2752 Time window done.
# 234 / 2752 Time window done.
# 235 / 2752 Time window done.
# 236 / 2752 Time window done.
# 237 / 2752 Time window done.
# 238 / 2752 Time window done.
# 239 / 2752 Time window done.
# 240 / 2752 Time window done.
# 241 / 2752 Time window done.
# 242 / 2752 Time window done.
# 243 / 2752 Time window done.
# 244 / 2752 Time window done.
# 245 / 2752 Time window done.
# 246 / 2752 Time window done.
# 247 / 2752 Time window done.
# 248 / 2752 Time window done.
# 249 / 2752 Time window done.
# 250 / 2752 Time window done.
# 251 / 2752 Time window done.
# 252 / 2752 Time window done.
# 253 / 2752 Time window done.
# 254 / 2752 Time window done.
# 255 / 2752 Time window done.
# 256 / 2752 Time window done.
# 257 / 2752 Time window done.
# 258 / 2752 Time window done.
# 259 / 2752 Time window done.
# 260 / 2752 Time window done.
# 261 / 2752 Time window done.
# 262 / 2752 Time window done.
# 263 / 2752 Time window done.
# 264 / 2752 Time window done.
# 265 / 2752 Time window done.
# 266 / 2752 Time window done.
# 267 / 2752 Time window done.
# 268 / 2752 Time window done.
# 269 / 2752 Time window done.
# 270 / 2752 Time window done.
# 271 / 2752 Time window done.
# 272 / 2752 Time window done.
# 273 / 2752 Time window done.
# 274 / 2752 Time window done.
# 275 / 2752 Time window done.
# 276 / 2752 Time window done.
# 277 / 2752 Time window done.
# 278 / 2752 Time window done.
# 279 / 2752 Time window done.
# 280 / 2752 Time window done.
# 281 / 2752 Time window done.
# 282 / 2752 Time window done.
# 283 / 2752 Time window done.
# 284 / 2752 Time window done.
# 285 / 2752 Time window done.
# 286 / 2752 Time window done.
# 287 / 2752 Time window done.
# 288 / 2752 Time window done.
# 289 / 2752 Time window done.
# 290 / 2752 Time window done.
# 291 / 2752 Time window done.
# 292 / 2752 Time window done.
# 293 / 2752 Time window done.
# 294 / 2752 Time window done.
# 295 / 2752 Time window done.
# 296 / 2752 Time window done.
# 297 / 2752 Time window done.
# 298 / 2752 Time window done.
# 299 / 2752 Time window done.
# 300 / 2752 Time window done.
# 301 / 2752 Time window done.
# 302 / 2752 Time window done.
# 303 / 2752 Time window done.
# 304 / 2752 Time window done.
# 305 / 2752 Time window done.
# 306 / 2752 Time window done.
# 307 / 2752 Time window done.
# 308 / 2752 Time window done.
# 309 / 2752 Time window done.
# 310 / 2752 Time window done.
# 311 / 2752 Time window done.
# 312 / 2752 Time window done.
# 313 / 2752 Time window done.
# 314 / 2752 Time window done.
# 315 / 2752 Time window done.
# 316 / 2752 Time window done.
# 317 / 2752 Time window done.
# 318 / 2752 Time window done.
# 319 / 2752 Time window done.
# 320 / 2752 Time window done.
# 321 / 2752 Time window done.
# 322 / 2752 Time window done.
# 323 / 2752 Time window done.
# 324 / 2752 Time window done.
# 325 / 2752 Time window done.
# 326 / 2752 Time window done.
# 327 / 2752 Time window done.
# 328 / 2752 Time window done.
# 329 / 2752 Time window done.
# 330 / 2752 Time window done.
# 331 / 2752 Time window done.
# 332 / 2752 Time window done.
# 333 / 2752 Time window done.
# 334 / 2752 Time window done.
# 335 / 2752 Time window done.
# 336 / 2752 Time window done.
# 337 / 2752 Time window done.
# 338 / 2752 Time window done.
# 339 / 2752 Time window done.
# 340 / 2752 Time window done.
# 341 / 2752 Time window done.
# 342 / 2752 Time window done.
# 343 / 2752 Time window done.
# 344 / 2752 Time window done.
# 345 / 2752 Time window done.
# 346 / 2752 Time window done.
# 347 / 2752 Time window done.
# 348 / 2752 Time window done.
# 349 / 2752 Time window done.
# 350 / 2752 Time window done.
# 351 / 2752 Time window done.
# 352 / 2752 Time window done.
# 353 / 2752 Time window done.
# 354 / 2752 Time window done.
# 355 / 2752 Time window done.
# 356 / 2752 Time window done.
# 357 / 2752 Time window done.
# 358 / 2752 Time window done.
# 359 / 2752 Time window done.
# 360 / 2752 Time window done.
# 361 / 2752 Time window done.
# 362 / 2752 Time window done.
# 363 / 2752 Time window done.
# 364 / 2752 Time window done.
# 365 / 2752 Time window done.
# 366 / 2752 Time window done.
# 367 / 2752 Time window done.
# 368 / 2752 Time window done.
# 369 / 2752 Time window done.
# 370 / 2752 Time window done.
# 371 / 2752 Time window done.
# 372 / 2752 Time window done.
# 373 / 2752 Time window done.
# 374 / 2752 Time window done.
# 375 / 2752 Time window done.
# 376 / 2752 Time window done.
# 377 / 2752 Time window done.
# 378 / 2752 Time window done.
# 379 / 2752 Time window done.
# 380 / 2752 Time window done.
# 381 / 2752 Time window done.
# 382 / 2752 Time window done.
# 383 / 2752 Time window done.
# 384 / 2752 Time window done.
# 385 / 2752 Time window done.
# 386 / 2752 Time window done.
# 387 / 2752 Time window done.
# 388 / 2752 Time window done.
# 389 / 2752 Time window done.
# 390 / 2752 Time window done.
# 391 / 2752 Time window done.
# 392 / 2752 Time window done.
# 393 / 2752 Time window done.
# 394 / 2752 Time window done.
# 395 / 2752 Time window done.
# 396 / 2752 Time window done.
# 397 / 2752 Time window done.
# 398 / 2752 Time window done.
# 399 / 2752 Time window done.
# 400 / 2752 Time window done.
# 401 / 2752 Time window done.
# 402 / 2752 Time window done.
# 403 / 2752 Time window done.
# 404 / 2752 Time window done.
# 405 / 2752 Time window done.
# 406 / 2752 Time window done.
# 407 / 2752 Time window done.
# 408 / 2752 Time window done.
# 409 / 2752 Time window done.
# 410 / 2752 Time window done.
# 411 / 2752 Time window done.
# 412 / 2752 Time window done.
# 413 / 2752 Time window done.
# 414 / 2752 Time window done.
# 415 / 2752 Time window done.
# 416 / 2752 Time window done.
# 417 / 2752 Time window done.
# 418 / 2752 Time window done.
# 419 / 2752 Time window done.
# 420 / 2752 Time window done.
# 421 / 2752 Time window done.
# 422 / 2752 Time window done.
# 423 / 2752 Time window done.
# 424 / 2752 Time window done.
# 425 / 2752 Time window done.
# 426 / 2752 Time window done.
# 427 / 2752 Time window done.
# 428 / 2752 Time window done.
# 429 / 2752 Time window done.
# 430 / 2752 Time window done.
# 431 / 2752 Time window done.
# 432 / 2752 Time window done.
# 433 / 2752 Time window done.
# 434 / 2752 Time window done.
# 435 / 2752 Time window done.
# 436 / 2752 Time window done.
# 437 / 2752 Time window done.
# 438 / 2752 Time window done.
# 439 / 2752 Time window done.
# 440 / 2752 Time window done.
# 441 / 2752 Time window done.
# 442 / 2752 Time window done.
# 443 / 2752 Time window done.
# 444 / 2752 Time window done.
# 445 / 2752 Time window done.
# 446 / 2752 Time window done.
# 447 / 2752 Time window done.
# 448 / 2752 Time window done.
# 449 / 2752 Time window done.
# 450 / 2752 Time window done.
# 451 / 2752 Time window done.
# 452 / 2752 Time window done.
# 453 / 2752 Time window done.
# 454 / 2752 Time window done.
# 455 / 2752 Time window done.
# 456 / 2752 Time window done.
# 457 / 2752 Time window done.
# 458 / 2752 Time window done.
# 459 / 2752 Time window done.
# 460 / 2752 Time window done.
# 461 / 2752 Time window done.
# 462 / 2752 Time window done.
# 463 / 2752 Time window done.
# 464 / 2752 Time window done.
# 465 / 2752 Time window done.
# 466 / 2752 Time window done.
# 467 / 2752 Time window done.
# 468 / 2752 Time window done.
# 469 / 2752 Time window done.
# 470 / 2752 Time window done.
# 471 / 2752 Time window done.
# 472 / 2752 Time window done.
# 473 / 2752 Time window done.
# 474 / 2752 Time window done.
# 475 / 2752 Time window done.
# 476 / 2752 Time window done.
# 477 / 2752 Time window done.
# 478 / 2752 Time window done.
# 479 / 2752 Time window done.
# 480 / 2752 Time window done.
# 481 / 2752 Time window done.
# 482 / 2752 Time window done.
# 483 / 2752 Time window done.
# 484 / 2752 Time window done.
# 485 / 2752 Time window done.
# 486 / 2752 Time window done.
# 487 / 2752 Time window done.
# 488 / 2752 Time window done.
# 489 / 2752 Time window done.
# 490 / 2752 Time window done.
# 491 / 2752 Time window done.
# 492 / 2752 Time window done.
# 493 / 2752 Time window done.
# 494 / 2752 Time window done.
# 495 / 2752 Time window done.
# 496 / 2752 Time window done.
# 497 / 2752 Time window done.
# 498 / 2752 Time window done.
# 499 / 2752 Time window done.
# 500 / 2752 Time window done.
# 501 / 2752 Time window done.
# 502 / 2752 Time window done.
# 503 / 2752 Time window done.
# 504 / 2752 Time window done.
# 505 / 2752 Time window done.
# 506 / 2752 Time window done.
# 507 / 2752 Time window done.
# 508 / 2752 Time window done.
# 509 / 2752 Time window done.
# 510 / 2752 Time window done.
# 511 / 2752 Time window done.
# 512 / 2752 Time window done.
# 513 / 2752 Time window done.
# 514 / 2752 Time window done.
# 515 / 2752 Time window done.
# 516 / 2752 Time window done.
# 517 / 2752 Time window done.
# 518 / 2752 Time window done.
# 519 / 2752 Time window done.
# 520 / 2752 Time window done.
# 521 / 2752 Time window done.
# 522 / 2752 Time window done.
# 523 / 2752 Time window done.
# 524 / 2752 Time window done.
# 525 / 2752 Time window done.
# 526 / 2752 Time window done.
# 527 / 2752 Time window done.
# 528 / 2752 Time window done.
# 529 / 2752 Time window done.
# 530 / 2752 Time window done.
# 531 / 2752 Time window done.
# 532 / 2752 Time window done.
# 533 / 2752 Time window done.
# 534 / 2752 Time window done.
# 535 / 2752 Time window done.
# 536 / 2752 Time window done.
# 537 / 2752 Time window done.
# 538 / 2752 Time window done.
# 539 / 2752 Time window done.
# 540 / 2752 Time window done.
# 541 / 2752 Time window done.
# 542 / 2752 Time window done.
# 543 / 2752 Time window done.
# 544 / 2752 Time window done.
# 545 / 2752 Time window done.
# 546 / 2752 Time window done.
# 547 / 2752 Time window done.
# 548 / 2752 Time window done.
# 549 / 2752 Time window done.
# 550 / 2752 Time window done.
# 551 / 2752 Time window done.
# 552 / 2752 Time window done.
# 553 / 2752 Time window done.
# 554 / 2752 Time window done.
# 555 / 2752 Time window done.
# 556 / 2752 Time window done.
# 557 / 2752 Time window done.
# 558 / 2752 Time window done.
# 559 / 2752 Time window done.
# 560 / 2752 Time window done.
# 561 / 2752 Time window done.
# 562 / 2752 Time window done.
# 563 / 2752 Time window done.
# 564 / 2752 Time window done.
# 565 / 2752 Time window done.
# 566 / 2752 Time window done.
# 567 / 2752 Time window done.
# 568 / 2752 Time window done.
# 569 / 2752 Time window done.
# 570 / 2752 Time window done.
# 571 / 2752 Time window done.
# 572 / 2752 Time window done.
# 573 / 2752 Time window done.
# 574 / 2752 Time window done.
# 575 / 2752 Time window done.
# 576 / 2752 Time window done.
# 577 / 2752 Time window done.
# 578 / 2752 Time window done.
# 579 / 2752 Time window done.
# 580 / 2752 Time window done.
# 581 / 2752 Time window done.
# 582 / 2752 Time window done.
# 583 / 2752 Time window done.
# 584 / 2752 Time window done.
# 585 / 2752 Time window done.
# 586 / 2752 Time window done.
# 587 / 2752 Time window done.
# 588 / 2752 Time window done.
# 589 / 2752 Time window done.
# 590 / 2752 Time window done.
# 591 / 2752 Time window done.
# 592 / 2752 Time window done.
# 593 / 2752 Time window done.
# 594 / 2752 Time window done.
# 595 / 2752 Time window done.
# 596 / 2752 Time window done.
# 597 / 2752 Time window done.
# 598 / 2752 Time window done.
# 599 / 2752 Time window done.
# 600 / 2752 Time window done.
# 601 / 2752 Time window done.
# 602 / 2752 Time window done.
# 603 / 2752 Time window done.
# 604 / 2752 Time window done.
# 605 / 2752 Time window done.
# 606 / 2752 Time window done.
# 607 / 2752 Time window done.
# 608 / 2752 Time window done.
# 609 / 2752 Time window done.
# 610 / 2752 Time window done.
# 611 / 2752 Time window done.
# 612 / 2752 Time window done.
# 613 / 2752 Time window done.
# 614 / 2752 Time window done.
# 615 / 2752 Time window done.
# 616 / 2752 Time window done.
# 617 / 2752 Time window done.
# 618 / 2752 Time window done.
# 619 / 2752 Time window done.
# 620 / 2752 Time window done.
# 621 / 2752 Time window done.
# 622 / 2752 Time window done.
# 623 / 2752 Time window done.
# 624 / 2752 Time window done.
# 625 / 2752 Time window done.
# 626 / 2752 Time window done.
# 627 / 2752 Time window done.
# 628 / 2752 Time window done.
# 629 / 2752 Time window done.
# 630 / 2752 Time window done.
# 631 / 2752 Time window done.
# 632 / 2752 Time window done.
# 633 / 2752 Time window done.
# 634 / 2752 Time window done.
# 635 / 2752 Time window done.
# 636 / 2752 Time window done.
# 637 / 2752 Time window done.
# 638 / 2752 Time window done.
# 639 / 2752 Time window done.
# 640 / 2752 Time window done.
# 641 / 2752 Time window done.
# 642 / 2752 Time window done.
# 643 / 2752 Time window done.
# 644 / 2752 Time window done.
# 645 / 2752 Time window done.
# 646 / 2752 Time window done.
# 647 / 2752 Time window done.
# 648 / 2752 Time window done.
# 649 / 2752 Time window done.
# 650 / 2752 Time window done.
# 651 / 2752 Time window done.
# 652 / 2752 Time window done.
# 653 / 2752 Time window done.
# 654 / 2752 Time window done.
# 655 / 2752 Time window done.
# 656 / 2752 Time window done.
# 657 / 2752 Time window done.
# 658 / 2752 Time window done.
# 659 / 2752 Time window done.
# 660 / 2752 Time window done.
# 661 / 2752 Time window done.
# 662 / 2752 Time window done.
# 663 / 2752 Time window done.
# 664 / 2752 Time window done.
# 665 / 2752 Time window done.
# 666 / 2752 Time window done.
# 667 / 2752 Time window done.
# 668 / 2752 Time window done.
# 669 / 2752 Time window done.
# 670 / 2752 Time window done.
# 671 / 2752 Time window done.
# 672 / 2752 Time window done.
# 673 / 2752 Time window done.
# 674 / 2752 Time window done.
# 675 / 2752 Time window done.
# 676 / 2752 Time window done.
# 677 / 2752 Time window done.
# 678 / 2752 Time window done.
# 679 / 2752 Time window done.
# 680 / 2752 Time window done.
# 681 / 2752 Time window done.
# 682 / 2752 Time window done.
# 683 / 2752 Time window done.
# 684 / 2752 Time window done.
# 685 / 2752 Time window done.
# 686 / 2752 Time window done.
# 687 / 2752 Time window done.
# 688 / 2752 Time window done.
# 689 / 2752 Time window done.
# 690 / 2752 Time window done.
# 691 / 2752 Time window done.
# 692 / 2752 Time window done.
# 693 / 2752 Time window done.
# 694 / 2752 Time window done.
# 695 / 2752 Time window done.
# 696 / 2752 Time window done.
# 697 / 2752 Time window done.
# 698 / 2752 Time window done.
# 699 / 2752 Time window done.
# 700 / 2752 Time window done.
# 701 / 2752 Time window done.
# 702 / 2752 Time window done.
# 703 / 2752 Time window done.
# 704 / 2752 Time window done.
# 705 / 2752 Time window done.
# 706 / 2752 Time window done.
# 707 / 2752 Time window done.
# 708 / 2752 Time window done.
# 709 / 2752 Time window done.
# 710 / 2752 Time window done.
# 711 / 2752 Time window done.
# 712 / 2752 Time window done.
# 713 / 2752 Time window done.
# 714 / 2752 Time window done.
# 715 / 2752 Time window done.
# 716 / 2752 Time window done.
# 717 / 2752 Time window done.
# 718 / 2752 Time window done.
# 719 / 2752 Time window done.
# 720 / 2752 Time window done.
# 721 / 2752 Time window done.
# 722 / 2752 Time window done.
# 723 / 2752 Time window done.
# 724 / 2752 Time window done.
# 725 / 2752 Time window done.
# 726 / 2752 Time window done.
# 727 / 2752 Time window done.
# 728 / 2752 Time window done.
# 729 / 2752 Time window done.
# 730 / 2752 Time window done.
# 731 / 2752 Time window done.
# 732 / 2752 Time window done.
# 733 / 2752 Time window done.
# 734 / 2752 Time window done.
# 735 / 2752 Time window done.
# 736 / 2752 Time window done.
# 737 / 2752 Time window done.
# 738 / 2752 Time window done.
# 739 / 2752 Time window done.
# 740 / 2752 Time window done.
# 741 / 2752 Time window done.
# 742 / 2752 Time window done.
# 743 / 2752 Time window done.
# 744 / 2752 Time window done.
# 745 / 2752 Time window done.
# 746 / 2752 Time window done.
# 747 / 2752 Time window done.
# 748 / 2752 Time window done.
# 749 / 2752 Time window done.
# 750 / 2752 Time window done.
# 751 / 2752 Time window done.
# 752 / 2752 Time window done.
# 753 / 2752 Time window done.
# 754 / 2752 Time window done.
# 755 / 2752 Time window done.
# 756 / 2752 Time window done.
# 757 / 2752 Time window done.
# 758 / 2752 Time window done.
# 759 / 2752 Time window done.
# 760 / 2752 Time window done.
# 761 / 2752 Time window done.
# 762 / 2752 Time window done.
# 763 / 2752 Time window done.
# 764 / 2752 Time window done.
# 765 / 2752 Time window done.
# 766 / 2752 Time window done.
# 767 / 2752 Time window done.
# 768 / 2752 Time window done.
# 769 / 2752 Time window done.
# 770 / 2752 Time window done.
# 771 / 2752 Time window done.
# 772 / 2752 Time window done.
# 773 / 2752 Time window done.
# 774 / 2752 Time window done.
# 775 / 2752 Time window done.
# 776 / 2752 Time window done.
# 777 / 2752 Time window done.
# 778 / 2752 Time window done.
# 779 / 2752 Time window done.
# 780 / 2752 Time window done.
# 781 / 2752 Time window done.
# 782 / 2752 Time window done.
# 783 / 2752 Time window done.
# 784 / 2752 Time window done.
# 785 / 2752 Time window done.
# 786 / 2752 Time window done.
# 787 / 2752 Time window done.
# 788 / 2752 Time window done.
# 789 / 2752 Time window done.
# 790 / 2752 Time window done.
# 791 / 2752 Time window done.
# 792 / 2752 Time window done.
# 793 / 2752 Time window done.
# 794 / 2752 Time window done.
# 795 / 2752 Time window done.
# 796 / 2752 Time window done.
# 797 / 2752 Time window done.
# 798 / 2752 Time window done.
# 799 / 2752 Time window done.
# 800 / 2752 Time window done.
# 801 / 2752 Time window done.
# 802 / 2752 Time window done.
# 803 / 2752 Time window done.
# 804 / 2752 Time window done.
# 805 / 2752 Time window done.
# 806 / 2752 Time window done.
# 807 / 2752 Time window done.
# 808 / 2752 Time window done.
# 809 / 2752 Time window done.
# 810 / 2752 Time window done.
# 811 / 2752 Time window done.
# 812 / 2752 Time window done.
# 813 / 2752 Time window done.
# 814 / 2752 Time window done.
# 815 / 2752 Time window done.
# 816 / 2752 Time window done.
# 817 / 2752 Time window done.
# 818 / 2752 Time window done.
# 819 / 2752 Time window done.
# 820 / 2752 Time window done.
# 821 / 2752 Time window done.
# 822 / 2752 Time window done.
# 823 / 2752 Time window done.
# 824 / 2752 Time window done.
# 825 / 2752 Time window done.
# 826 / 2752 Time window done.
# 827 / 2752 Time window done.
# 828 / 2752 Time window done.
# 829 / 2752 Time window done.
# 830 / 2752 Time window done.
# 831 / 2752 Time window done.
# 832 / 2752 Time window done.
# 833 / 2752 Time window done.
# 834 / 2752 Time window done.
# 835 / 2752 Time window done.
# 836 / 2752 Time window done.
# 837 / 2752 Time window done.
# 838 / 2752 Time window done.
# 839 / 2752 Time window done.
# 840 / 2752 Time window done.
# 841 / 2752 Time window done.
# 842 / 2752 Time window done.
# 843 / 2752 Time window done.
# 844 / 2752 Time window done.
# 845 / 2752 Time window done.
# 846 / 2752 Time window done.
# 847 / 2752 Time window done.
# 848 / 2752 Time window done.
# 849 / 2752 Time window done.
# 850 / 2752 Time window done.
# 851 / 2752 Time window done.
# 852 / 2752 Time window done.
# 853 / 2752 Time window done.
# 854 / 2752 Time window done.
# 855 / 2752 Time window done.
# 856 / 2752 Time window done.
# 857 / 2752 Time window done.
# 858 / 2752 Time window done.
# 859 / 2752 Time window done.
# 860 / 2752 Time window done.
# 861 / 2752 Time window done.
# 862 / 2752 Time window done.
# 863 / 2752 Time window done.
# 864 / 2752 Time window done.
# 865 / 2752 Time window done.
# 866 / 2752 Time window done.
# 867 / 2752 Time window done.
# 868 / 2752 Time window done.
# 869 / 2752 Time window done.
# 870 / 2752 Time window done.
# 871 / 2752 Time window done.
# 872 / 2752 Time window done.
# 873 / 2752 Time window done.
# 874 / 2752 Time window done.
# 875 / 2752 Time window done.
# 876 / 2752 Time window done.
# 877 / 2752 Time window done.
# 878 / 2752 Time window done.
# 879 / 2752 Time window done.
# 880 / 2752 Time window done.
# 881 / 2752 Time window done.
# 882 / 2752 Time window done.
# 883 / 2752 Time window done.
# 884 / 2752 Time window done.
# 885 / 2752 Time window done.
# 886 / 2752 Time window done.
# 887 / 2752 Time window done.
# 888 / 2752 Time window done.
# 889 / 2752 Time window done.
# 890 / 2752 Time window done.
# 891 / 2752 Time window done.
# 892 / 2752 Time window done.
# 893 / 2752 Time window done.
# 894 / 2752 Time window done.
# 895 / 2752 Time window done.
# 896 / 2752 Time window done.
# 897 / 2752 Time window done.
# 898 / 2752 Time window done.
# 899 / 2752 Time window done.
# 900 / 2752 Time window done.
# 901 / 2752 Time window done.
# 902 / 2752 Time window done.
# 903 / 2752 Time window done.
# 904 / 2752 Time window done.
# 905 / 2752 Time window done.
# 906 / 2752 Time window done.
# 907 / 2752 Time window done.
# 908 / 2752 Time window done.
# 909 / 2752 Time window done.
# 910 / 2752 Time window done.
# 911 / 2752 Time window done.
# 912 / 2752 Time window done.
# 913 / 2752 Time window done.
# 914 / 2752 Time window done.
# 915 / 2752 Time window done.
# 916 / 2752 Time window done.
# 917 / 2752 Time window done.
# 918 / 2752 Time window done.
# 919 / 2752 Time window done.
# 920 / 2752 Time window done.
# 921 / 2752 Time window done.
# 922 / 2752 Time window done.
# 923 / 2752 Time window done.
# 924 / 2752 Time window done.
# 925 / 2752 Time window done.
# 926 / 2752 Time window done.
# 927 / 2752 Time window done.
# 928 / 2752 Time window done.
# 929 / 2752 Time window done.
# 930 / 2752 Time window done.
# 931 / 2752 Time window done.
# 932 / 2752 Time window done.
# 933 / 2752 Time window done.
# 934 / 2752 Time window done.
# 935 / 2752 Time window done.
# 936 / 2752 Time window done.
# 937 / 2752 Time window done.
# 938 / 2752 Time window done.
# 939 / 2752 Time window done.
# 940 / 2752 Time window done.
# 941 / 2752 Time window done.
# 942 / 2752 Time window done.
# 943 / 2752 Time window done.
# 944 / 2752 Time window done.
# 945 / 2752 Time window done.
# 946 / 2752 Time window done.
# 947 / 2752 Time window done.
# 948 / 2752 Time window done.
# 949 / 2752 Time window done.
# 950 / 2752 Time window done.
# 951 / 2752 Time window done.
# 952 / 2752 Time window done.
# 953 / 2752 Time window done.
# 954 / 2752 Time window done.
# 955 / 2752 Time window done.
# 956 / 2752 Time window done.
# 957 / 2752 Time window done.
# 958 / 2752 Time window done.
# 959 / 2752 Time window done.
# 960 / 2752 Time window done.
# 961 / 2752 Time window done.
# 962 / 2752 Time window done.
# 963 / 2752 Time window done.
# 964 / 2752 Time window done.
# 965 / 2752 Time window done.
# 966 / 2752 Time window done.
# 967 / 2752 Time window done.
# 968 / 2752 Time window done.
# 969 / 2752 Time window done.
# 970 / 2752 Time window done.
# 971 / 2752 Time window done.
# 972 / 2752 Time window done.
# 973 / 2752 Time window done.
# 974 / 2752 Time window done.
# 975 / 2752 Time window done.
# 976 / 2752 Time window done.
# 977 / 2752 Time window done.
# 978 / 2752 Time window done.
# 979 / 2752 Time window done.
# 980 / 2752 Time window done.
# 981 / 2752 Time window done.
# 982 / 2752 Time window done.
# 983 / 2752 Time window done.
# 984 / 2752 Time window done.
# 985 / 2752 Time window done.
# 986 / 2752 Time window done.
# 987 / 2752 Time window done.
# 988 / 2752 Time window done.
# 989 / 2752 Time window done.
# 990 / 2752 Time window done.
# 991 / 2752 Time window done.
# 992 / 2752 Time window done.
# 993 / 2752 Time window done.
# 994 / 2752 Time window done.
# 995 / 2752 Time window done.
# 996 / 2752 Time window done.
# 997 / 2752 Time window done.
# 998 / 2752 Time window done.
# 999 / 2752 Time window done.
# 1000 / 2752 Time window done.
# 1001 / 2752 Time window done.
# 1002 / 2752 Time window done.
# 1003 / 2752 Time window done.
# 1004 / 2752 Time window done.
# 1005 / 2752 Time window done.
# 1006 / 2752 Time window done.
# 1007 / 2752 Time window done.
# 1008 / 2752 Time window done.
# 1009 / 2752 Time window done.
# 1010 / 2752 Time window done.
# 1011 / 2752 Time window done.
# 1012 / 2752 Time window done.
# 1013 / 2752 Time window done.
# 1014 / 2752 Time window done.
# 1015 / 2752 Time window done.
# 1016 / 2752 Time window done.
# 1017 / 2752 Time window done.
# 1018 / 2752 Time window done.
# 1019 / 2752 Time window done.
# 1020 / 2752 Time window done.
# 1021 / 2752 Time window done.
# 1022 / 2752 Time window done.
# 1023 / 2752 Time window done.
# 1024 / 2752 Time window done.
# 1025 / 2752 Time window done.
# 1026 / 2752 Time window done.
# 1027 / 2752 Time window done.
# 1028 / 2752 Time window done.
# 1029 / 2752 Time window done.
# 1030 / 2752 Time window done.
# 1031 / 2752 Time window done.
# 1032 / 2752 Time window done.
# 1033 / 2752 Time window done.
# 1034 / 2752 Time window done.
# 1035 / 2752 Time window done.
# 1036 / 2752 Time window done.
# 1037 / 2752 Time window done.
# 1038 / 2752 Time window done.
# 1039 / 2752 Time window done.
# 1040 / 2752 Time window done.
# 1041 / 2752 Time window done.
# 1042 / 2752 Time window done.
# 1043 / 2752 Time window done.
# 1044 / 2752 Time window done.
# 1045 / 2752 Time window done.
# 1046 / 2752 Time window done.
# 1047 / 2752 Time window done.
# 1048 / 2752 Time window done.
# 1049 / 2752 Time window done.
# 1050 / 2752 Time window done.
# 1051 / 2752 Time window done.
# 1052 / 2752 Time window done.
# 1053 / 2752 Time window done.
# 1054 / 2752 Time window done.
# 1055 / 2752 Time window done.
# 1056 / 2752 Time window done.
# 1057 / 2752 Time window done.
# 1058 / 2752 Time window done.
# 1059 / 2752 Time window done.
# 1060 / 2752 Time window done.
# 1061 / 2752 Time window done.
# 1062 / 2752 Time window done.
# 1063 / 2752 Time window done.
# 1064 / 2752 Time window done.
# 1065 / 2752 Time window done.
# 1066 / 2752 Time window done.
# 1067 / 2752 Time window done.
# 1068 / 2752 Time window done.
# 1069 / 2752 Time window done.
# 1070 / 2752 Time window done.
# 1071 / 2752 Time window done.
# 1072 / 2752 Time window done.
# 1073 / 2752 Time window done.
# 1074 / 2752 Time window done.
# 1075 / 2752 Time window done.
# 1076 / 2752 Time window done.
# 1077 / 2752 Time window done.
# 1078 / 2752 Time window done.
# 1079 / 2752 Time window done.
# 1080 / 2752 Time window done.
# 1081 / 2752 Time window done.
# 1082 / 2752 Time window done.
# 1083 / 2752 Time window done.
# 1084 / 2752 Time window done.
# 1085 / 2752 Time window done.
# 1086 / 2752 Time window done.
# 1087 / 2752 Time window done.
# 1088 / 2752 Time window done.
# 1089 / 2752 Time window done.
# 1090 / 2752 Time window done.
# 1091 / 2752 Time window done.
# 1092 / 2752 Time window done.
# 1093 / 2752 Time window done.
# 1094 / 2752 Time window done.
# 1095 / 2752 Time window done.
# 1096 / 2752 Time window done.
# 1097 / 2752 Time window done.
# 1098 / 2752 Time window done.
# 1099 / 2752 Time window done.
# 1100 / 2752 Time window done.
# 1101 / 2752 Time window done.
# 1102 / 2752 Time window done.
# 1103 / 2752 Time window done.
# 1104 / 2752 Time window done.
# 1105 / 2752 Time window done.
# 1106 / 2752 Time window done.
# 1107 / 2752 Time window done.
# 1108 / 2752 Time window done.
# 1109 / 2752 Time window done.
# 1110 / 2752 Time window done.
# 1111 / 2752 Time window done.
# 1112 / 2752 Time window done.
# 1113 / 2752 Time window done.
# 1114 / 2752 Time window done.
# 1115 / 2752 Time window done.
# 1116 / 2752 Time window done.
# 1117 / 2752 Time window done.
# 1118 / 2752 Time window done.
# 1119 / 2752 Time window done.
# 1120 / 2752 Time window done.
# 1121 / 2752 Time window done.
# 1122 / 2752 Time window done.
# 1123 / 2752 Time window done.
# 1124 / 2752 Time window done.
# 1125 / 2752 Time window done.
# 1126 / 2752 Time window done.
# 1127 / 2752 Time window done.
# 1128 / 2752 Time window done.
# 1129 / 2752 Time window done.
# 1130 / 2752 Time window done.
# 1131 / 2752 Time window done.
# 1132 / 2752 Time window done.
# 1133 / 2752 Time window done.
# 1134 / 2752 Time window done.
# 1135 / 2752 Time window done.
# 1136 / 2752 Time window done.
# 1137 / 2752 Time window done.
# 1138 / 2752 Time window done.
# 1139 / 2752 Time window done.
# 1140 / 2752 Time window done.
# 1141 / 2752 Time window done.
# 1142 / 2752 Time window done.
# 1143 / 2752 Time window done.
# 1144 / 2752 Time window done.
# 1145 / 2752 Time window done.
# 1146 / 2752 Time window done.
# 1147 / 2752 Time window done.
# 1148 / 2752 Time window done.
# 1149 / 2752 Time window done.
# 1150 / 2752 Time window done.
# 1151 / 2752 Time window done.
# 1152 / 2752 Time window done.
# 1153 / 2752 Time window done.
# 1154 / 2752 Time window done.
# 1155 / 2752 Time window done.
# 1156 / 2752 Time window done.
# 1157 / 2752 Time window done.
# 1158 / 2752 Time window done.
# 1159 / 2752 Time window done.
# 1160 / 2752 Time window done.
# 1161 / 2752 Time window done.
# 1162 / 2752 Time window done.
# 1163 / 2752 Time window done.
# 1164 / 2752 Time window done.
# 1165 / 2752 Time window done.
# 1166 / 2752 Time window done.
# 1167 / 2752 Time window done.
# 1168 / 2752 Time window done.
# 1169 / 2752 Time window done.
# 1170 / 2752 Time window done.
# 1171 / 2752 Time window done.
# 1172 / 2752 Time window done.
# 1173 / 2752 Time window done.
# 1174 / 2752 Time window done.
# 1175 / 2752 Time window done.
# 1176 / 2752 Time window done.
# 1177 / 2752 Time window done.
# 1178 / 2752 Time window done.
# 1179 / 2752 Time window done.
# 1180 / 2752 Time window done.
# 1181 / 2752 Time window done.
# 1182 / 2752 Time window done.
# 1183 / 2752 Time window done.
# 1184 / 2752 Time window done.
# 1185 / 2752 Time window done.
# 1186 / 2752 Time window done.
# 1187 / 2752 Time window done.
# 1188 / 2752 Time window done.
# 1189 / 2752 Time window done.
# 1190 / 2752 Time window done.
# 1191 / 2752 Time window done.
# 1192 / 2752 Time window done.
# 1193 / 2752 Time window done.
# 1194 / 2752 Time window done.
# 1195 / 2752 Time window done.
# 1196 / 2752 Time window done.
# 1197 / 2752 Time window done.
# 1198 / 2752 Time window done.
# 1199 / 2752 Time window done.
# 1200 / 2752 Time window done.
# 1201 / 2752 Time window done.
# 1202 / 2752 Time window done.
# 1203 / 2752 Time window done.
# 1204 / 2752 Time window done.
# 1205 / 2752 Time window done.
# 1206 / 2752 Time window done.
# 1207 / 2752 Time window done.
# 1208 / 2752 Time window done.
# 1209 / 2752 Time window done.
# 1210 / 2752 Time window done.
# 1211 / 2752 Time window done.
# 1212 / 2752 Time window done.
# 1213 / 2752 Time window done.
# 1214 / 2752 Time window done.
# 1215 / 2752 Time window done.
# 1216 / 2752 Time window done.
# 1217 / 2752 Time window done.
# 1218 / 2752 Time window done.
# 1219 / 2752 Time window done.
# 1220 / 2752 Time window done.
# 1221 / 2752 Time window done.
# 1222 / 2752 Time window done.
# 1223 / 2752 Time window done.
# 1224 / 2752 Time window done.
# 1225 / 2752 Time window done.
# 1226 / 2752 Time window done.
# 1227 / 2752 Time window done.
# 1228 / 2752 Time window done.
# 1229 / 2752 Time window done.
# 1230 / 2752 Time window done.
# 1231 / 2752 Time window done.
# 1232 / 2752 Time window done.
# 1233 / 2752 Time window done.
# 1234 / 2752 Time window done.
# 1235 / 2752 Time window done.
# 1236 / 2752 Time window done.
# 1237 / 2752 Time window done.
# 1238 / 2752 Time window done.
# 1239 / 2752 Time window done.
# 1240 / 2752 Time window done.
# 1241 / 2752 Time window done.
# 1242 / 2752 Time window done.
# 1243 / 2752 Time window done.
# 1244 / 2752 Time window done.
# 1245 / 2752 Time window done.
# 1246 / 2752 Time window done.
# 1247 / 2752 Time window done.
# 1248 / 2752 Time window done.
# 1249 / 2752 Time window done.
# 1250 / 2752 Time window done.
# 1251 / 2752 Time window done.
# 1252 / 2752 Time window done.
# 1253 / 2752 Time window done.
# 1254 / 2752 Time window done.
# 1255 / 2752 Time window done.
# 1256 / 2752 Time window done.
# 1257 / 2752 Time window done.
# 1258 / 2752 Time window done.
# 1259 / 2752 Time window done.
# 1260 / 2752 Time window done.
# 1261 / 2752 Time window done.
# 1262 / 2752 Time window done.
# 1263 / 2752 Time window done.
# 1264 / 2752 Time window done.
# 1265 / 2752 Time window done.
# 1266 / 2752 Time window done.
# 1267 / 2752 Time window done.
# 1268 / 2752 Time window done.
# 1269 / 2752 Time window done.
# 1270 / 2752 Time window done.
# 1271 / 2752 Time window done.
# 1272 / 2752 Time window done.
# 1273 / 2752 Time window done.
# 1274 / 2752 Time window done.
# 1275 / 2752 Time window done.
# 1276 / 2752 Time window done.
# 1277 / 2752 Time window done.
# 1278 / 2752 Time window done.
# 1279 / 2752 Time window done.
# 1280 / 2752 Time window done.
# 1281 / 2752 Time window done.
# 1282 / 2752 Time window done.
# 1283 / 2752 Time window done.
# 1284 / 2752 Time window done.
# 1285 / 2752 Time window done.
# 1286 / 2752 Time window done.
# 1287 / 2752 Time window done.
# 1288 / 2752 Time window done.
# 1289 / 2752 Time window done.
# 1290 / 2752 Time window done.
# 1291 / 2752 Time window done.
# 1292 / 2752 Time window done.
# 1293 / 2752 Time window done.
# 1294 / 2752 Time window done.
# 1295 / 2752 Time window done.
# 1296 / 2752 Time window done.
# 1297 / 2752 Time window done.
# 1298 / 2752 Time window done.
# 1299 / 2752 Time window done.
# 1300 / 2752 Time window done.
# 1301 / 2752 Time window done.
# 1302 / 2752 Time window done.
# 1303 / 2752 Time window done.
# 1304 / 2752 Time window done.
# 1305 / 2752 Time window done.
# 1306 / 2752 Time window done.
# 1307 / 2752 Time window done.
# 1308 / 2752 Time window done.
# 1309 / 2752 Time window done.
# 1310 / 2752 Time window done.
# 1311 / 2752 Time window done.
# 1312 / 2752 Time window done.
# 1313 / 2752 Time window done.
# 1314 / 2752 Time window done.
# 1315 / 2752 Time window done.
# 1316 / 2752 Time window done.
# 1317 / 2752 Time window done.
# 1318 / 2752 Time window done.
# 1319 / 2752 Time window done.
# 1320 / 2752 Time window done.
# 1321 / 2752 Time window done.
# 1322 / 2752 Time window done.
# 1323 / 2752 Time window done.
# 1324 / 2752 Time window done.
# 1325 / 2752 Time window done.
# 1326 / 2752 Time window done.
# 1327 / 2752 Time window done.
# 1328 / 2752 Time window done.
# 1329 / 2752 Time window done.
# 1330 / 2752 Time window done.
# 1331 / 2752 Time window done.
# 1332 / 2752 Time window done.
# 1333 / 2752 Time window done.
# 1334 / 2752 Time window done.
# 1335 / 2752 Time window done.
# 1336 / 2752 Time window done.
# 1337 / 2752 Time window done.
# 1338 / 2752 Time window done.
# 1339 / 2752 Time window done.
# 1340 / 2752 Time window done.
# 1341 / 2752 Time window done.
# 1342 / 2752 Time window done.
# 1343 / 2752 Time window done.
# 1344 / 2752 Time window done.
# 1345 / 2752 Time window done.
# 1346 / 2752 Time window done.
# 1347 / 2752 Time window done.
# 1348 / 2752 Time window done.
# 1349 / 2752 Time window done.
# 1350 / 2752 Time window done.
# 1351 / 2752 Time window done.
# 1352 / 2752 Time window done.
# 1353 / 2752 Time window done.
# 1354 / 2752 Time window done.
# 1355 / 2752 Time window done.
# 1356 / 2752 Time window done.
# 1357 / 2752 Time window done.
# 1358 / 2752 Time window done.
# 1359 / 2752 Time window done.
# 1360 / 2752 Time window done.
# 1361 / 2752 Time window done.
# 1362 / 2752 Time window done.
# 1363 / 2752 Time window done.
# 1364 / 2752 Time window done.
# 1365 / 2752 Time window done.
# 1366 / 2752 Time window done.
# 1367 / 2752 Time window done.
# 1368 / 2752 Time window done.
# 1369 / 2752 Time window done.
# 1370 / 2752 Time window done.
# 1371 / 2752 Time window done.
# 1372 / 2752 Time window done.
# 1373 / 2752 Time window done.
# 1374 / 2752 Time window done.
# 1375 / 2752 Time window done.
# 1376 / 2752 Time window done.
# 1377 / 2752 Time window done.
# 1378 / 2752 Time window done.
# 1379 / 2752 Time window done.
# 1380 / 2752 Time window done.
# 1381 / 2752 Time window done.
# 1382 / 2752 Time window done.
# 1383 / 2752 Time window done.
# 1384 / 2752 Time window done.
# 1385 / 2752 Time window done.
# 1386 / 2752 Time window done.
# 1387 / 2752 Time window done.
# 1388 / 2752 Time window done.
# 1389 / 2752 Time window done.
# 1390 / 2752 Time window done.
# 1391 / 2752 Time window done.
# 1392 / 2752 Time window done.
# 1393 / 2752 Time window done.
# 1394 / 2752 Time window done.
# 1395 / 2752 Time window done.
# 1396 / 2752 Time window done.
# 1397 / 2752 Time window done.
# 1398 / 2752 Time window done.
# 1399 / 2752 Time window done.
# 1400 / 2752 Time window done.
# 1401 / 2752 Time window done.
# 1402 / 2752 Time window done.
# 1403 / 2752 Time window done.
# 1404 / 2752 Time window done.
# 1405 / 2752 Time window done.
# 1406 / 2752 Time window done.
# 1407 / 2752 Time window done.
# 1408 / 2752 Time window done.
# 1409 / 2752 Time window done.
# 1410 / 2752 Time window done.
# 1411 / 2752 Time window done.
# 1412 / 2752 Time window done.
# 1413 / 2752 Time window done.
# 1414 / 2752 Time window done.
# 1415 / 2752 Time window done.
# 1416 / 2752 Time window done.
# 1417 / 2752 Time window done.
# 1418 / 2752 Time window done.
# 1419 / 2752 Time window done.
# 1420 / 2752 Time window done.
# 1421 / 2752 Time window done.
# 1422 / 2752 Time window done.
# 1423 / 2752 Time window done.
# 1424 / 2752 Time window done.
# 1425 / 2752 Time window done.
# 1426 / 2752 Time window done.
# 1427 / 2752 Time window done.
# 1428 / 2752 Time window done.
# 1429 / 2752 Time window done.
# 1430 / 2752 Time window done.
# 1431 / 2752 Time window done.
# 1432 / 2752 Time window done.
# 1433 / 2752 Time window done.
# 1434 / 2752 Time window done.
# 1435 / 2752 Time window done.
# 1436 / 2752 Time window done.
# 1437 / 2752 Time window done.
# 1438 / 2752 Time window done.
# 1439 / 2752 Time window done.
# 1440 / 2752 Time window done.
# 1441 / 2752 Time window done.
# 1442 / 2752 Time window done.
# 1443 / 2752 Time window done.
# 1444 / 2752 Time window done.
# 1445 / 2752 Time window done.
# 1446 / 2752 Time window done.
# 1447 / 2752 Time window done.
# 1448 / 2752 Time window done.
# 1449 / 2752 Time window done.
# 1450 / 2752 Time window done.
# 1451 / 2752 Time window done.
# 1452 / 2752 Time window done.
# 1453 / 2752 Time window done.
# 1454 / 2752 Time window done.
# 1455 / 2752 Time window done.
# 1456 / 2752 Time window done.
# 1457 / 2752 Time window done.
# 1458 / 2752 Time window done.
# 1459 / 2752 Time window done.
# 1460 / 2752 Time window done.
# 1461 / 2752 Time window done.
# 1462 / 2752 Time window done.
# 1463 / 2752 Time window done.
# 1464 / 2752 Time window done.
# 1465 / 2752 Time window done.
# 1466 / 2752 Time window done.
# 1467 / 2752 Time window done.
# 1468 / 2752 Time window done.
# 1469 / 2752 Time window done.
# 1470 / 2752 Time window done.
# 1471 / 2752 Time window done.
# 1472 / 2752 Time window done.
# 1473 / 2752 Time window done.
# 1474 / 2752 Time window done.
# 1475 / 2752 Time window done.
# 1476 / 2752 Time window done.
# 1477 / 2752 Time window done.
# 1478 / 2752 Time window done.
# 1479 / 2752 Time window done.
# 1480 / 2752 Time window done.
# 1481 / 2752 Time window done.
# 1482 / 2752 Time window done.
# 1483 / 2752 Time window done.
# 1484 / 2752 Time window done.
# 1485 / 2752 Time window done.
# 1486 / 2752 Time window done.
# 1487 / 2752 Time window done.
# 1488 / 2752 Time window done.
# 1489 / 2752 Time window done.
# 1490 / 2752 Time window done.
# 1491 / 2752 Time window done.
# 1492 / 2752 Time window done.
# 1493 / 2752 Time window done.
# 1494 / 2752 Time window done.
# 1495 / 2752 Time window done.
# 1496 / 2752 Time window done.
# 1497 / 2752 Time window done.
# 1498 / 2752 Time window done.
# 1499 / 2752 Time window done.
# 1500 / 2752 Time window done.
# 1501 / 2752 Time window done.
# 1502 / 2752 Time window done.
# 1503 / 2752 Time window done.
# 1504 / 2752 Time window done.
# 1505 / 2752 Time window done.
# 1506 / 2752 Time window done.
# 1507 / 2752 Time window done.
# 1508 / 2752 Time window done.
# 1509 / 2752 Time window done.
# 1510 / 2752 Time window done.
# 1511 / 2752 Time window done.
# 1512 / 2752 Time window done.
# 1513 / 2752 Time window done.
# 1514 / 2752 Time window done.
# 1515 / 2752 Time window done.
# 1516 / 2752 Time window done.
# 1517 / 2752 Time window done.
# 1518 / 2752 Time window done.
# 1519 / 2752 Time window done.
# 1520 / 2752 Time window done.
# 1521 / 2752 Time window done.
# 1522 / 2752 Time window done.
# 1523 / 2752 Time window done.
# 1524 / 2752 Time window done.
# 1525 / 2752 Time window done.
# 1526 / 2752 Time window done.
# 1527 / 2752 Time window done.
# 1528 / 2752 Time window done.
# 1529 / 2752 Time window done.
# 1530 / 2752 Time window done.
# 1531 / 2752 Time window done.
# 1532 / 2752 Time window done.
# 1533 / 2752 Time window done.
# 1534 / 2752 Time window done.
# 1535 / 2752 Time window done.
# 1536 / 2752 Time window done.
# 1537 / 2752 Time window done.
# 1538 / 2752 Time window done.
# 1539 / 2752 Time window done.
# 1540 / 2752 Time window done.
# 1541 / 2752 Time window done.
# 1542 / 2752 Time window done.
# 1543 / 2752 Time window done.
# 1544 / 2752 Time window done.
# 1545 / 2752 Time window done.
# 1546 / 2752 Time window done.
# 1547 / 2752 Time window done.
# 1548 / 2752 Time window done.
# 1549 / 2752 Time window done.
# 1550 / 2752 Time window done.
# 1551 / 2752 Time window done.
# 1552 / 2752 Time window done.
# 1553 / 2752 Time window done.
# 1554 / 2752 Time window done.
# 1555 / 2752 Time window done.
# 1556 / 2752 Time window done.
# 1557 / 2752 Time window done.
# 1558 / 2752 Time window done.
# 1559 / 2752 Time window done.
# 1560 / 2752 Time window done.
# 1561 / 2752 Time window done.
# 1562 / 2752 Time window done.
# 1563 / 2752 Time window done.
# 1564 / 2752 Time window done.
# 1565 / 2752 Time window done.
# 1566 / 2752 Time window done.
# 1567 / 2752 Time window done.
# 1568 / 2752 Time window done.
# 1569 / 2752 Time window done.
# 1570 / 2752 Time window done.
# 1571 / 2752 Time window done.
# 1572 / 2752 Time window done.
# 1573 / 2752 Time window done.
# 1574 / 2752 Time window done.
# 1575 / 2752 Time window done.
# 1576 / 2752 Time window done.
# 1577 / 2752 Time window done.
# 1578 / 2752 Time window done.
# 1579 / 2752 Time window done.
# 1580 / 2752 Time window done.
# 1581 / 2752 Time window done.
# 1582 / 2752 Time window done.
# 1583 / 2752 Time window done.
# 1584 / 2752 Time window done.
# 1585 / 2752 Time window done.
# 1586 / 2752 Time window done.
# 1587 / 2752 Time window done.
# 1588 / 2752 Time window done.
# 1589 / 2752 Time window done.
# 1590 / 2752 Time window done.
# 1591 / 2752 Time window done.
# 1592 / 2752 Time window done.
# 1593 / 2752 Time window done.
# 1594 / 2752 Time window done.
# 1595 / 2752 Time window done.
# 1596 / 2752 Time window done.
# 1597 / 2752 Time window done.
# 1598 / 2752 Time window done.
# 1599 / 2752 Time window done.
# 1600 / 2752 Time window done.
# 1601 / 2752 Time window done.
# 1602 / 2752 Time window done.
# 1603 / 2752 Time window done.
# 1604 / 2752 Time window done.
# 1605 / 2752 Time window done.
# 1606 / 2752 Time window done.
# 1607 / 2752 Time window done.
# 1608 / 2752 Time window done.
# 1609 / 2752 Time window done.
# 1610 / 2752 Time window done.
# 1611 / 2752 Time window done.
# 1612 / 2752 Time window done.
# 1613 / 2752 Time window done.
# 1614 / 2752 Time window done.
# 1615 / 2752 Time window done.
# 1616 / 2752 Time window done.
# 1617 / 2752 Time window done.
# 1618 / 2752 Time window done.
# 1619 / 2752 Time window done.
# 1620 / 2752 Time window done.
# 1621 / 2752 Time window done.
# 1622 / 2752 Time window done.
# 1623 / 2752 Time window done.
# 1624 / 2752 Time window done.
# 1625 / 2752 Time window done.
# 1626 / 2752 Time window done.
# 1627 / 2752 Time window done.
# 1628 / 2752 Time window done.
# 1629 / 2752 Time window done.
# 1630 / 2752 Time window done.
# 1631 / 2752 Time window done.
# 1632 / 2752 Time window done.
# 1633 / 2752 Time window done.
# 1634 / 2752 Time window done.
# 1635 / 2752 Time window done.
# 1636 / 2752 Time window done.
# ...
# 2218 / 2752 Time window done.
# 2219 / 2752 Time window done.
# 2220 / 2752 Time window done.
# 2221 / 2752 Time window done.
# 2222 / 2752 Time window done.
# 2223 / 2752 Time window done.
# 2224 / 2752 Time window done.
# 2225 / 2752 Time window done.
# 2226 / 2752 Time window done.
# 2227 / 2752 Time window done.
# 2228 / 2752 Time window done.
# 2229 / 2752 Time window done.
# 2230 / 2752 Time window done.
# 2231 / 2752 Time window done.
# 2232 / 2752 Time window done.
# 2233 / 2752 Time window done.
# 2234 / 2752 Time window done.
# 2235 / 2752 Time window done.
# 2236 / 2752 Time window done.
# 2237 / 2752 Time window done.
# 2238 / 2752 Time window done.
# 2239 / 2752 Time window done.
# 2240 / 2752 Time window done.
# 2241 / 2752 Time window done.
# 2242 / 2752 Time window done.
# 2243 / 2752 Time window done.
# 2244 / 2752 Time window done.
# 2245 / 2752 Time window done.
# 2246 / 2752 Time window done.
# 2247 / 2752 Time window done.
# 2248 / 2752 Time window done.
# 2249 / 2752 Time window done.
# 2250 / 2752 Time window done.
# 2251 / 2752 Time window done.
# 2252 / 2752 Time window done.
# 2253 / 2752 Time window done.
# 2254 / 2752 Time window done.
# 2255 / 2752 Time window done.
# 2256 / 2752 Time window done.
# 2257 / 2752 Time window done.
# 2258 / 2752 Time window done.
# 2259 / 2752 Time window done.
# 2260 / 2752 Time window done.
# 2261 / 2752 Time window done.
# 2262 / 2752 Time window done.
# 2263 / 2752 Time window done.
# 2264 / 2752 Time window done.
# 2265 / 2752 Time window done.
# 2266 / 2752 Time window done.
# 2267 / 2752 Time window done.
# 2268 / 2752 Time window done.
# 2269 / 2752 Time window done.
# 2270 / 2752 Time window done.
# 2271 / 2752 Time window done.
# 2272 / 2752 Time window done.
# 2273 / 2752 Time window done.
# 2274 / 2752 Time window done.
# 2275 / 2752 Time window done.
# 2276 / 2752 Time window done.
# 2277 / 2752 Time window done.
# 2278 / 2752 Time window done.
# 2279 / 2752 Time window done.
# 2280 / 2752 Time window done.
# 2281 / 2752 Time window done.
# 2282 / 2752 Time window done.
# 2283 / 2752 Time window done.
# 2284 / 2752 Time window done.
# 2285 / 2752 Time window done.
# 2286 / 2752 Time window done.
# 2287 / 2752 Time window done.
# 2288 / 2752 Time window done.
# 2289 / 2752 Time window done.
# 2290 / 2752 Time window done.
# 2291 / 2752 Time window done.
# 2292 / 2752 Time window done.
# 2293 / 2752 Time window done.
# 2294 / 2752 Time window done.
# 2295 / 2752 Time window done.
# 2296 / 2752 Time window done.
# 2297 / 2752 Time window done.
# 2298 / 2752 Time window done.
# 2299 / 2752 Time window done.
# 2300 / 2752 Time window done.
# 2301 / 2752 Time window done.
# 2302 / 2752 Time window done.
# 2303 / 2752 Time window done.
# 2304 / 2752 Time window done.
# 2305 / 2752 Time window done.
# 2306 / 2752 Time window done.
# 2307 / 2752 Time window done.
# 2308 / 2752 Time window done.
# 2309 / 2752 Time window done.
# 2310 / 2752 Time window done.
# 2311 / 2752 Time window done.
# 2312 / 2752 Time window done.
# 2313 / 2752 Time window done.
# 2314 / 2752 Time window done.
# 2315 / 2752 Time window done.
# 2316 / 2752 Time window done.
# 2317 / 2752 Time window done.
# 2318 / 2752 Time window done.
# 2319 / 2752 Time window done.
# 2320 / 2752 Time window done.
# 2321 / 2752 Time window done.
# 2322 / 2752 Time window done.
# 2323 / 2752 Time window done.
# 2324 / 2752 Time window done.
# 2325 / 2752 Time window done.
# 2326 / 2752 Time window done.
# 2327 / 2752 Time window done.
# 2328 / 2752 Time window done.
# 2329 / 2752 Time window done.
# 2330 / 2752 Time window done.
# 2331 / 2752 Time window done.
# 2332 / 2752 Time window done.
# 2333 / 2752 Time window done.
# 2334 / 2752 Time window done.
# 2335 / 2752 Time window done.
# 2336 / 2752 Time window done.
# 2337 / 2752 Time window done.
# 2338 / 2752 Time window done.
# 2339 / 2752 Time window done.
# 2340 / 2752 Time window done.
# 2341 / 2752 Time window done.
# 2342 / 2752 Time window done.
# 2343 / 2752 Time window done.
# 2344 / 2752 Time window done.
# 2345 / 2752 Time window done.
# 2346 / 2752 Time window done.
# 2347 / 2752 Time window done.
# 2348 / 2752 Time window done.
# 2349 / 2752 Time window done.
# 2350 / 2752 Time window done.
# 2351 / 2752 Time window done.
# 2352 / 2752 Time window done.
# 2353 / 2752 Time window done.
# 2354 / 2752 Time window done.
# 2355 / 2752 Time window done.
# 2356 / 2752 Time window done.
# 2357 / 2752 Time window done.
# 2358 / 2752 Time window done.
# 2359 / 2752 Time window done.
# 2360 / 2752 Time window done.
# 2361 / 2752 Time window done.
# 2362 / 2752 Time window done.
# 2363 / 2752 Time window done.
# 2364 / 2752 Time window done.
# 2365 / 2752 Time window done.
# 2366 / 2752 Time window done.
# 2367 / 2752 Time window done.
# 2368 / 2752 Time window done.
# 2369 / 2752 Time window done.
# 2370 / 2752 Time window done.
# 2371 / 2752 Time window done.
# 2372 / 2752 Time window done.
# 2373 / 2752 Time window done.
# 2374 / 2752 Time window done.
# 2375 / 2752 Time window done.
# 2376 / 2752 Time window done.
# 2377 / 2752 Time window done.
# 2378 / 2752 Time window done.
# 2379 / 2752 Time window done.
# 2380 / 2752 Time window done.
# 2381 / 2752 Time window done.
# 2382 / 2752 Time window done.
# 2383 / 2752 Time window done.
# 2384 / 2752 Time window done.
# 2385 / 2752 Time window done.
# 2386 / 2752 Time window done.
# 2387 / 2752 Time window done.
# 2388 / 2752 Time window done.
# 2389 / 2752 Time window done.
# 2390 / 2752 Time window done.
# 2391 / 2752 Time window done.
# 2392 / 2752 Time window done.
# 2393 / 2752 Time window done.
# 2394 / 2752 Time window done.
# 2395 / 2752 Time window done.
# 2396 / 2752 Time window done.
# 2397 / 2752 Time window done.
# 2398 / 2752 Time window done.
# 2399 / 2752 Time window done.
# 2400 / 2752 Time window done.
# 2401 / 2752 Time window done.
# 2402 / 2752 Time window done.
# 2403 / 2752 Time window done.
# 2404 / 2752 Time window done.
# 2405 / 2752 Time window done.
# 2406 / 2752 Time window done.
# 2407 / 2752 Time window done.
# 2408 / 2752 Time window done.
# 2409 / 2752 Time window done.
# 2410 / 2752 Time window done.
# 2411 / 2752 Time window done.
# 2412 / 2752 Time window done.
# 2413 / 2752 Time window done.
# 2414 / 2752 Time window done.
# 2415 / 2752 Time window done.
# 2416 / 2752 Time window done.
# 2417 / 2752 Time window done.
# 2418 / 2752 Time window done.
# 2419 / 2752 Time window done.
# 2420 / 2752 Time window done.
# 2421 / 2752 Time window done.
# 2422 / 2752 Time window done.
# 2423 / 2752 Time window done.
# 2424 / 2752 Time window done.
# 2425 / 2752 Time window done.
# 2426 / 2752 Time window done.
# 2427 / 2752 Time window done.
# 2428 / 2752 Time window done.
# 2429 / 2752 Time window done.
# 2430 / 2752 Time window done.
# 2431 / 2752 Time window done.
# 2432 / 2752 Time window done.
# 2433 / 2752 Time window done.
# 2434 / 2752 Time window done.
# 2435 / 2752 Time window done.
# 2436 / 2752 Time window done.
# 2437 / 2752 Time window done.
# 2438 / 2752 Time window done.
# 2439 / 2752 Time window done.
# 2440 / 2752 Time window done.
# 2441 / 2752 Time window done.
# 2442 / 2752 Time window done.
# 2443 / 2752 Time window done.
# 2444 / 2752 Time window done.
# 2445 / 2752 Time window done.
# 2446 / 2752 Time window done.
# 2447 / 2752 Time window done.
# 2448 / 2752 Time window done.
# 2449 / 2752 Time window done.
# 2450 / 2752 Time window done.
# 2451 / 2752 Time window done.
# 2452 / 2752 Time window done.
# 2453 / 2752 Time window done.
# 2454 / 2752 Time window done.
# 2455 / 2752 Time window done.
# 2456 / 2752 Time window done.
# 2457 / 2752 Time window done.
# 2458 / 2752 Time window done.
# 2459 / 2752 Time window done.
# 2460 / 2752 Time window done.
# 2461 / 2752 Time window done.
# 2462 / 2752 Time window done.
# 2463 / 2752 Time window done.
# 2464 / 2752 Time window done.
# 2465 / 2752 Time window done.
# 2466 / 2752 Time window done.
# 2467 / 2752 Time window done.
# 2468 / 2752 Time window done.
# 2469 / 2752 Time window done.
# 2470 / 2752 Time window done.
# 2471 / 2752 Time window done.
# 2472 / 2752 Time window done.
# 2473 / 2752 Time window done.
# 2474 / 2752 Time window done.
# 2475 / 2752 Time window done.
# 2476 / 2752 Time window done.
# 2477 / 2752 Time window done.
# 2478 / 2752 Time window done.
# 2479 / 2752 Time window done.
# 2480 / 2752 Time window done.
# 2481 / 2752 Time window done.
# 2482 / 2752 Time window done.
# 2483 / 2752 Time window done.
# 2484 / 2752 Time window done.
# 2485 / 2752 Time window done.
# 2486 / 2752 Time window done.
# 2487 / 2752 Time window done.
# 2488 / 2752 Time window done.
# 2489 / 2752 Time window done.
# 2490 / 2752 Time window done.
# 2491 / 2752 Time window done.
# 2492 / 2752 Time window done.
# 2493 / 2752 Time window done.
# 2494 / 2752 Time window done.
# 2495 / 2752 Time window done.
# 2496 / 2752 Time window done.
# 2497 / 2752 Time window done.
# 2498 / 2752 Time window done.
# 2499 / 2752 Time window done.
# 2500 / 2752 Time window done.
# 2501 / 2752 Time window done.
# 2502 / 2752 Time window done.
# 2503 / 2752 Time window done.
# 2504 / 2752 Time window done.
# 2505 / 2752 Time window done.
# 2506 / 2752 Time window done.
# 2507 / 2752 Time window done.
# 2508 / 2752 Time window done.
# 2509 / 2752 Time window done.
# 2510 / 2752 Time window done.
# 2511 / 2752 Time window done.
# 2512 / 2752 Time window done.
# 2513 / 2752 Time window done.
# 2514 / 2752 Time window done.
# 2515 / 2752 Time window done.
# 2516 / 2752 Time window done.
# 2517 / 2752 Time window done.
# 2518 / 2752 Time window done.
# 2519 / 2752 Time window done.
# 2520 / 2752 Time window done.
# 2521 / 2752 Time window done.
# 2522 / 2752 Time window done.
# 2523 / 2752 Time window done.
# 2524 / 2752 Time window done.
# 2525 / 2752 Time window done.
# 2526 / 2752 Time window done.
# 2527 / 2752 Time window done.
# 2528 / 2752 Time window done.
# 2529 / 2752 Time window done.
# 2530 / 2752 Time window done.
# 2531 / 2752 Time window done.
# 2532 / 2752 Time window done.
# 2533 / 2752 Time window done.
# 2534 / 2752 Time window done.
# 2535 / 2752 Time window done.
# 2536 / 2752 Time window done.
# 2537 / 2752 Time window done.
# 2538 / 2752 Time window done.
# 2539 / 2752 Time window done.
# 2540 / 2752 Time window done.
# 2541 / 2752 Time window done.
# 2542 / 2752 Time window done.
# 2543 / 2752 Time window done.
# 2544 / 2752 Time window done.
# 2545 / 2752 Time window done.
# 2546 / 2752 Time window done.
# 2547 / 2752 Time window done.
# 2548 / 2752 Time window done.
# 2549 / 2752 Time window done.
# 2550 / 2752 Time window done.
# 2551 / 2752 Time window done.
# 2552 / 2752 Time window done.
# 2553 / 2752 Time window done.
# 2554 / 2752 Time window done.
# 2555 / 2752 Time window done.
# 2556 / 2752 Time window done.
# 2557 / 2752 Time window done.
# 2558 / 2752 Time window done.
# 2559 / 2752 Time window done.
# 2560 / 2752 Time window done.
# 2561 / 2752 Time window done.
# 2562 / 2752 Time window done.
# 2563 / 2752 Time window done.
# 2564 / 2752 Time window done.
# 2565 / 2752 Time window done.
# 2566 / 2752 Time window done.
# 2567 / 2752 Time window done.
# 2568 / 2752 Time window done.
# 2569 / 2752 Time window done.
# 2570 / 2752 Time window done.
# 2571 / 2752 Time window done.
# 2572 / 2752 Time window done.
# 2573 / 2752 Time window done.
# 2574 / 2752 Time window done.
# 2575 / 2752 Time window done.
# 2576 / 2752 Time window done.
# 2577 / 2752 Time window done.
# 2578 / 2752 Time window done.
# 2579 / 2752 Time window done.
# 2580 / 2752 Time window done.
# 2581 / 2752 Time window done.
# 2582 / 2752 Time window done.
# 2583 / 2752 Time window done.
# 2584 / 2752 Time window done.
# 2585 / 2752 Time window done.
# 2586 / 2752 Time window done.
# 2587 / 2752 Time window done.
# 2588 / 2752 Time window done.
# 2589 / 2752 Time window done.
# 2590 / 2752 Time window done.
# 2591 / 2752 Time window done.
# 2592 / 2752 Time window done.
# 2593 / 2752 Time window done.
# 2594 / 2752 Time window done.
# 2595 / 2752 Time window done.
# 2596 / 2752 Time window done.
# 2597 / 2752 Time window done.
# 2598 / 2752 Time window done.
# 2599 / 2752 Time window done.
# 2600 / 2752 Time window done.
# 2601 / 2752 Time window done.
# 2602 / 2752 Time window done.
# 2603 / 2752 Time window done.
# 2604 / 2752 Time window done.
# 2605 / 2752 Time window done.
# 2606 / 2752 Time window done.
# 2607 / 2752 Time window done.
# 2608 / 2752 Time window done.
# 2609 / 2752 Time window done.
# 2610 / 2752 Time window done.
# 2611 / 2752 Time window done.
# 2612 / 2752 Time window done.
# 2613 / 2752 Time window done.
# 2614 / 2752 Time window done.
# 2615 / 2752 Time window done.
# 2616 / 2752 Time window done.
# 2617 / 2752 Time window done.
# 2618 / 2752 Time window done.
# 2619 / 2752 Time window done.
# 2620 / 2752 Time window done.
# 2621 / 2752 Time window done.
# 2622 / 2752 Time window done.
# 2623 / 2752 Time window done.
# 2624 / 2752 Time window done.
# 2625 / 2752 Time window done.
# 2626 / 2752 Time window done.
# 2627 / 2752 Time window done.
# 2628 / 2752 Time window done.
# 2629 / 2752 Time window done.
# 2630 / 2752 Time window done.
# 2631 / 2752 Time window done.
# 2632 / 2752 Time window done.
# 2633 / 2752 Time window done.
# 2634 / 2752 Time window done.
# 2635 / 2752 Time window done.
# 2636 / 2752 Time window done.
# 2637 / 2752 Time window done.
# 2638 / 2752 Time window done.
# 2639 / 2752 Time window done.
# 2640 / 2752 Time window done.
# 2641 / 2752 Time window done.
# 2642 / 2752 Time window done.
# 2643 / 2752 Time window done.
# 2644 / 2752 Time window done.
# 2645 / 2752 Time window done.
# 2646 / 2752 Time window done.
# 2647 / 2752 Time window done.
# 2648 / 2752 Time window done.
# 2649 / 2752 Time window done.
# 2650 / 2752 Time window done.
# 2651 / 2752 Time window done.
# 2652 / 2752 Time window done.
# 2653 / 2752 Time window done.
# 2654 / 2752 Time window done.
# 2655 / 2752 Time window done.
# 2656 / 2752 Time window done.
# 2657 / 2752 Time window done.
# 2658 / 2752 Time window done.
# 2659 / 2752 Time window done.
# 2660 / 2752 Time window done.
# 2661 / 2752 Time window done.
# 2662 / 2752 Time window done.
# 2663 / 2752 Time window done.
# 2664 / 2752 Time window done.
# 2665 / 2752 Time window done.
# 2666 / 2752 Time window done.
# 2667 / 2752 Time window done.
# 2668 / 2752 Time window done.
# 2669 / 2752 Time window done.
# 2670 / 2752 Time window done.
# 2671 / 2752 Time window done.
# 2672 / 2752 Time window done.
# 2673 / 2752 Time window done.
# 2674 / 2752 Time window done.
# 2675 / 2752 Time window done.
# 2676 / 2752 Time window done.
# 2677 / 2752 Time window done.
# 2678 / 2752 Time window done.
# 2679 / 2752 Time window done.
# 2680 / 2752 Time window done.
# 2681 / 2752 Time window done.
# 2682 / 2752 Time window done.
# 2683 / 2752 Time window done.
# 2684 / 2752 Time window done.
# 2685 / 2752 Time window done.
# 2686 / 2752 Time window done.
# 2687 / 2752 Time window done.
# 2688 / 2752 Time window done.
# 2689 / 2752 Time window done.
# 2690 / 2752 Time window done.
# 2691 / 2752 Time window done.
# 2692 / 2752 Time window done.
# 2693 / 2752 Time window done.
# 2694 / 2752 Time window done.
# 2695 / 2752 Time window done.
# 2696 / 2752 Time window done.
# 2697 / 2752 Time window done.
# 2698 / 2752 Time window done.
# 2699 / 2752 Time window done.
# 2700 / 2752 Time window done.
# 2701 / 2752 Time window done.
# 2702 / 2752 Time window done.
# 2703 / 2752 Time window done.
# 2704 / 2752 Time window done.
# 2705 / 2752 Time window done.
# 2706 / 2752 Time window done.
# 2707 / 2752 Time window done.
# 2708 / 2752 Time window done.
# 2709 / 2752 Time window done.
# 2710 / 2752 Time window done.
# 2711 / 2752 Time window done.
# 2712 / 2752 Time window done.
# 2713 / 2752 Time window done.
# 2714 / 2752 Time window done.
# 2715 / 2752 Time window done.
# 2716 / 2752 Time window done.
# 2717 / 2752 Time window done.
# 2718 / 2752 Time window done.
# 2719 / 2752 Time window done.
# 2720 / 2752 Time window done.
# 2721 / 2752 Time window done.
# 2722 / 2752 Time window done.
# 2723 / 2752 Time window done.
# 2724 / 2752 Time window done.
# 2725 / 2752 Time window done.
# 2726 / 2752 Time window done.
# 2727 / 2752 Time window done.
# 2728 / 2752 Time window done.
# 2729 / 2752 Time window done.
# 2730 / 2752 Time window done.
# 2731 / 2752 Time window done.
# 2732 / 2752 Time window done.
# 2733 / 2752 Time window done.
# 2734 / 2752 Time window done.
# 2735 / 2752 Time window done.
# 2736 / 2752 Time window done.
# 2737 / 2752 Time window done.
# 2738 / 2752 Time window done.
# 2739 / 2752 Time window done.
# 2740 / 2752 Time window done.
# 2741 / 2752 Time window done.
# 2742 / 2752 Time window done.
# 2743 / 2752 Time window done.
# 2744 / 2752 Time window done.
# 2745 / 2752 Time window done.
# 2746 / 2752 Time window done.
# 2747 / 2752 Time window done.
# 2748 / 2752 Time window done.
# 2749 / 2752 Time window done.
# Whole dataset done.

# %%
print(f"AUC: {roc_auc_score(iscx_results.label, iscx_results.scores):.3f}")
print(f"Total time: {anograph_time:.2f}s")
# Out:
# AUC: 0.949
# Total time: 55.54s

# %% [markdown]
# ## AnoEdge Global

# %%
rows = 2
buckets = 32
decay_factor = 0.9
anoedge = AnoEdgeGlobal(rows, buckets, decay_factor)

# %%
def evaluate_edge(stream, model, n_wait=100000):
    """
    Evaluate a streaming model on a given data stream for edge anomaly detection.

    Parameters
    ----------
    stream : iterable
        A data stream where each element is a tuple (x, _), where x is a dictionary containing
        data for the model to learn, and _ is a placeholder for any additional information.
    model :
        The streaming model to evaluate.
    n_wait : int
        The number of observations to wait before printing progress information. Default is 100,000.

    Returns
    -------
    results : pandas.DataFrame
        A DataFrame containing evaluation results, including scores for each time window.
    """
    # Initialize results DataFrame with ISCX AnoEdge labels
    results = iscx_label_anoedge.copy()
    results['scores'] = 0.0
    
    # Iterate over the data stream
    for i, (x,_) in enumerate(stream):
        # Update the model with the current data point
        model.learn_one(x)
        
        # Score the current data point and update results
        results.loc[i, 'scores'] = model.score_one(x)
        if i % n_wait == 0 and i > 0:
            # Print progress information
            print(f"{i} observations done")

    return results

# %%
anoedge_start = time.time()
iscx_results_edge = evaluate_edge(stream=iter_pandas(X=iscx),
                       model=anoedge)
anoedge_time = time.time() - anoedge_start
# Out:
# 100000 observations done
# 200000 observations done
# 300000 observations done
# 400000 observations done
# 500000 observations done
# 600000 observations done
# 700000 observations done
# 800000 observations done
# 900000 observations done
# 1000000 observations done

# %%
print(f"AUC: {roc_auc_score(iscx_results_edge.label, iscx_results_edge.scores):.3f}")
print(f"Total time: {anoedge_time:.2f}s")
# Out:
# AUC: 0.954
# Total time: 1343.42s
